# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def convertStrToArr(string_data):
    values = string_data.strip('[]').split()
    # return np.array([float(value) for value in values])
    return [float(value) for value in values]

# %%
# 0 - 0.5 20pt
delta_sp1 =convertStrToArr("""[-0.10176928 -0.08317506 -0.06514577 -0.0476814  -0.03078196 -0.01444744
  0.00132216  0.01652683  0.03116657  0.0452414   0.0587513   0.07169627
  0.08407632  0.09589145  0.10714165  0.11782693  0.12794728  0.13750271
  0.14649322  0.1549188 ]""")
omega_sp1 = convertStrToArr("""[38.4056902  38.39495664 38.37348952 38.35202241 38.33055529 38.30908817
 38.28762106 38.26615394 38.24468682 38.22321971 38.20175259 38.18028547
 38.15881836 38.13735124 38.11588412 38.094417   38.07294989 38.05148277
 38.03001565 38.0192821 ]""")

# 0.5 - 1 20pt
delta_sp2 =convertStrToArr("""[0.15569136 0.16302209 0.16993998 0.17644503 0.18253724 0.18821661
 0.19348314 0.19833683 0.20277768 0.20680569 0.21042085 0.21362318
 0.21641266 0.21878931 0.22075311 0.22230408 0.2234422  0.22416748
 0.22447992 0.22437953]""")
omega_sp2 = convertStrToArr("""[37.9776778  37.96983383 37.95414589 37.93845795 37.92277001 37.90708207
 37.89139413 37.87570618 37.86001824 37.8443303  37.82864236 37.81295442
 37.79726647 37.78157853 37.76589059 37.75020265 37.73451471 37.71882677
 37.70313882 37.69529485]""")

# 1 - 1.5 20pt
delta_sp3 = convertStrToArr("""[0.22443999 0.22423616 0.22387186 0.22334711 0.22266189 0.22181622
 0.22081009 0.2196435  0.21831644 0.21682893 0.21518096 0.21337253
 0.21140364 0.20927429 0.20698448 0.20453422 0.20192349 0.1991523
 0.19622065 0.19312855]""")
omega_sp3 = convertStrToArr("""[37.69136426 37.68831553 37.68221807 37.67612061 37.67002315 37.66392569
 37.65782823 37.65173076 37.6456333  37.63953584 37.63343838 37.62734092
 37.62124346 37.615146   37.60904853 37.60295107 37.59685361 37.59075615
 37.58465869 37.58160996]""")

# 1.5 - 2 20pt
delta_sp4 = convertStrToArr("""[0.19328275 0.19017299 0.18693442 0.18356705 0.18007086 0.17644588
 0.17269208 0.16880949 0.16479808 0.16065787 0.15638885 0.15199103
 0.1474644  0.14280897 0.13802473 0.13311168 0.12806983 0.12289917
 0.11759971 0.11217144]""")
omega_sp4 = convertStrToArr("""[37.58093899 37.57849168 37.57359705 37.56870243 37.5638078  37.55891318
 37.55401855 37.54912393 37.54422931 37.53933468 37.53444006 37.52954543
 37.52465081 37.51975618 37.51486156 37.50996693 37.50507231 37.50017768
 37.49528306 37.49283575]""")

# 2 - 2.5 20pt
delta_sp5 = convertStrToArr("""[0.11267441 0.10739258 0.1022385  0.0972122  0.09231365 0.08754287
 0.08289986 0.07838461 0.07399712 0.0697374  0.06560544 0.06160124
 0.05772481 0.05397615 0.05035525 0.04686211 0.04349673 0.04025913
 0.03714928 0.0341672 ]""")
omega_sp5 = convertStrToArr("""[37.49840022 37.50082774 37.50568278 37.51053782 37.51539286 37.5202479
 37.52510294 37.52995798 37.53481301 37.53966805 37.54452309 37.54937813
 37.55423317 37.55908821 37.56394325 37.56879829 37.57365333 37.57850837
 37.58336341 37.58579092]""")

# 2.5 - 3 20pt
delta_sp6 = convertStrToArr("""[0.03408206 0.03123203 0.02861615 0.02623442 0.02408682 0.02217338
 0.02049407 0.01904891 0.0178379  0.01686103 0.0161183  0.01560971
 0.01533527 0.01529498 0.01548883 0.01591682 0.01657896 0.01747524
 0.01860566 0.01997023]""")
omega_sp6 = convertStrToArr("""[37.59080909 37.59525782 37.6041553  37.61305277 37.62195024 37.63084772
 37.63974519 37.64864266 37.65754014 37.66643761 37.67533508 37.68423256
 37.69313003 37.7020275  37.71092498 37.71982245 37.72871992 37.7376174
 37.74651487 37.75096361]""")

# 3 - 3.5 20pt
delta_sp7 = convertStrToArr("""[0.01962612 0.02106559 0.02252448 0.02400277 0.02550047 0.02701758
 0.02855409 0.03011002 0.03168535 0.03328009 0.03489424 0.03652779
 0.03818075 0.03985313 0.0415449  0.04325609 0.04498669 0.04673669
 0.0485061  0.05029492]""")
omega_sp7 = convertStrToArr("""[37.75381011 37.75417886 37.75491636 37.75565386 37.75639136 37.75712886
 37.75786636 37.75860386 37.75934136 37.76007885 37.76081635 37.76155385
 37.76229135 37.76302885 37.76376635 37.76450385 37.76524135 37.76597885
 37.76671634 37.76708509]""")

# 3.5 - 4 20pt
delta_sp8 = convertStrToArr("""[0.05024126 0.05197111 0.05360687 0.05514853 0.0565961  0.05794957
 0.05920896 0.06037424 0.06144543 0.06242253 0.06330554 0.06409444
 0.06478926 0.06538998 0.06589661 0.06630914 0.06662758 0.06685192
 0.06698217 0.06701833]""")
omega_sp8 = convertStrToArr("""[37.76484438 37.76305658 37.759481   37.75590542 37.75232984 37.74875426
 37.74517867 37.74160309 37.73802751 37.73445193 37.73087634 37.72730076
 37.72372518 37.7201496  37.71657402 37.71299843 37.70942285 37.70584727
 37.70227169 37.7004839 ]""")

# 4 - 4.5 20pt
delta_sp9 = convertStrToArr("""[0.06716333 0.06662648 0.06608595 0.06554176 0.06499389 0.06444235
 0.06388714 0.06332825 0.06276569 0.06219946 0.06162956 0.06105598
 0.06047873 0.05989781 0.05931322 0.05872495 0.05813301 0.0575374
 0.05693812 0.05633516]""")
omega_sp9 = convertStrToArr("""[37.67870969 37.67863991 37.67850035 37.67836079 37.67822124 37.67808168
 37.67794212 37.67780257 37.67766301 37.67752345 37.6773839  37.67724434
 37.67710478 37.67696522 37.67682567 37.67668611 37.67654655 37.676407
 37.67626744 37.67619766]""")

# %%
# 0 - 0.5 20pt
delta_sp1_s =convertStrToArr("""[-0.10057676 -0.08249165 -0.06454233 -0.04678765 -0.02928564 -0.01209325
  0.00473371  0.02114079  0.03707506  0.05248523  0.0673218   0.08153725
  0.0950861   0.1079251   0.12001334  0.13131235  0.14178622  0.1514017
  0.16012832  0.16793843]""")
omega_sp1_s = convertStrToArr("""[38.38634428 38.38376425 38.37748586 38.36898709 38.35830365 38.34547751
 38.33055683 38.31359575 38.29465428 38.27379811 38.25109841 38.22663161
 38.20047925 38.17272763 38.14346768 38.11279462 38.0808077  38.04760994
 38.01330781 37.99589417]""")

# 0.5 - 1 20pt
delta_sp2_s =convertStrToArr("""[0.1676094  0.17522398 0.18220815 0.18859244 0.19440764 0.19968462
 0.2044543  0.20874744 0.21259459 0.21602595 0.21907127 0.2217597
 0.22411977 0.22617918 0.22796478 0.22950243 0.23081694 0.23193195
 0.23286985 0.23365173]""")
omega_sp2_s = convertStrToArr("""[37.98846404 37.97648623 37.9531108  37.93090029 37.90986147 37.88999661
 37.87130351 37.85377555 37.83740174 37.82216681 37.80805128 37.79503154
 37.78308    37.77216518 37.76225185 37.75330116 37.74527084 37.73811529
 37.73178583 37.72882133]""")

# 1 - 1.5 20pt
delta_sp3_s = convertStrToArr("""[0.2315315  0.23201417 0.2323502  0.23253897 0.23258014 0.23247363
 0.23221964 0.23181862 0.23127134 0.23057879 0.22974225 0.22876326
 0.22764363 0.22638541 0.22499091 0.22346268 0.22180353 0.22001646
 0.21810473 0.21607181]""")
omega_sp3_s = convertStrToArr("""[37.71745141 37.71466532 37.70908136 37.70347897 37.69786852 37.69226035
 37.68666485 37.68109233 37.67555307 37.67005727 37.66461502 37.65923627
 37.65393083 37.64870834 37.64357822 37.63854968 37.63363166 37.62883288
 37.62416174 37.62185911]""")

# 1.5 - 2 20pt
delta_sp4_s = convertStrToArr("""[0.21609916 0.21400887 0.21177807 0.20940403 0.2068843  0.20421674
 0.2013995  0.19843109 0.19531033 0.19203639 0.1886088  0.18502744
 0.18129258 0.17740484 0.17336525 0.16917519 0.16483645 0.1603512
 0.15572201 0.15095182]""")
omega_sp4_s = convertStrToArr("""[37.61967885 37.61700926 37.61161809 37.60612841 37.60055144 37.59489884
 37.58918274 37.5834157  37.57761064 37.57178087 37.56593998 37.56010187
 37.55428068 37.54849074 37.54274658 37.53706283 37.53145424 37.52593558
 37.52052166 37.51784274]""")

# 2 - 2.5 20pt
delta_sp5_s = convertStrToArr("""[0.15073767 0.14588394 0.14088508 0.13575977 0.13052693 0.12520568
 0.11981528 0.11437505 0.10890435 0.1034225  0.09794873 0.09250211
 0.08710152 0.08176559 0.07651262 0.07136055 0.06632691 0.06142877
 0.05668265 0.05210454]""")
omega_sp5_s = convertStrToArr("""[37.51466832 37.5119108  37.50675067 37.50230508 37.49858234 37.49558864
 37.49332804 37.49180245 37.49101161 37.49095315 37.49162253 37.4930131
 37.49511613 37.49792079 37.50141424 37.50558161 37.5104061  37.515869
 37.52194975 37.5251419 ]""")

# 2.5 - 3 20pt
delta_sp6_s = convertStrToArr("""[0.05208558 0.04763957 0.04344335 0.03950361 0.03582629 0.03241659
 0.02927896 0.0264171  0.02383391 0.02153153 0.01951132 0.01777387
 0.01631898 0.01514569 0.01425225 0.01363618 0.01329424 0.01322246
 0.01341614 0.01386988]""")
omega_sp6_s = convertStrToArr("""[37.53016176 37.53490779 37.54452677 37.55438571 37.56445658 37.57471088
 37.58511972 37.59565396 37.60628419 37.6169809  37.62771452 37.63845551
 37.64917443 37.65984206 37.67042943 37.68090792 37.69124935 37.70142607
 37.71141098 37.71635214]""")

# 3 - 3.5 20pt
delta_sp7_s = convertStrToArr("""[0.01380279 0.01435816 0.01509774 0.01601619 0.01710683 0.01836167
 0.01977144 0.02132562 0.02301245 0.024819   0.0267312  0.02873387
 0.03081078 0.03294473 0.03511754 0.03731019 0.0395028  0.04167477
 0.04380479 0.04587092]""")
omega_sp7_s = convertStrToArr("""[37.72021406 37.72371405 37.7306125  37.73728259 37.74367409 37.74973767
 37.75542505 37.76068917 37.76548431 37.76976625 37.77349243 37.77662209
 37.77911637 37.78093848 37.78205379 37.78242996 37.78203706 37.78084765
 37.77883691 37.77762326]""")

# 3.5 - 4 20pt
delta_sp8_s = convertStrToArr("""[0.04621568 0.04821767 0.05014405 0.05199067 0.05375358 0.05542911
 0.05701381 0.05850451 0.0598983  0.06119254 0.06238489 0.06347327
 0.06445592 0.06533136 0.06609841 0.0667562  0.06730416 0.06774202
 0.06806981 0.06828788]""")
omega_sp8_s = convertStrToArr("""[37.77518556 37.77374904 37.77079693 37.76769105 37.76444039 37.76105435
 37.75754263 37.75391527 37.7501826  37.7463552  37.74244388 37.73845965
 37.73441369 37.73031734 37.726182   37.72201919 37.71784045 37.71365734
 37.70948139 37.70739665]""")

# 4 - 4.5 20pt
delta_sp9_s = convertStrToArr("""[0.06847785 0.06869356 0.06880675 0.06882178 0.06874322 0.06857581
 0.06832448 0.06799428 0.06759042 0.06711822 0.06658309 0.06599053
 0.06534611 0.06465543 0.06392413 0.06315784 0.06236221 0.06154283
 0.06070528 0.05985504]""")
omega_sp9_s = convertStrToArr("""[37.70730695 37.70535905 37.70154617 37.69790291 37.69443658 37.69115387
 37.68806083 37.68516289 37.68246482 37.67997072 37.67768402 37.67560746
 37.67374311 37.67209233 37.67065581 37.66943354 37.66842481 37.66762826
 37.66704182 37.66680084]""")

# %%
# X1 = np.linspace(0, 0.5, 20).tolist()  
# X2 = np.linspace(0.5, 1, 20).tolist()  
# X3 = np.linspace(1, 1.5, 20).tolist()
# X4 = np.linspace(1.5, 2, 20).tolist()
# X = []
# X.extend(X1)
# X.extend(X2)
# X.extend(X3)
# X.extend(X4)
# print(len(X))

# %%
delta0_4 = delta_sp1 + delta_sp2 + delta_sp3 + delta_sp4 + delta_sp5 + delta_sp6 + delta_sp7 + delta_sp8 + delta_sp9 

omega0_4 = omega_sp1 + omega_sp2 + omega_sp3 + omega_sp4 + omega_sp5 + omega_sp6 + omega_sp7 + omega_sp8 + omega_sp9 


print(type(delta_sp1))
print(len(delta0_4))
print(len(omega0_4))

delta0_4_s = delta_sp1_s + delta_sp2_s + delta_sp3_s + delta_sp4_s + delta_sp5_s + delta_sp6_s + delta_sp7_s + delta_sp8_s + delta_sp9_s 

omega0_4_s = omega_sp1_s + omega_sp2_s + omega_sp3_s + omega_sp4_s + omega_sp5_s + omega_sp6_s + omega_sp7_s + omega_sp8_s + omega_sp9_s
# Out:
# <class 'list'>
# 180
# 180

# %%
# X_real = np.linspace(0, 8, 20*(int(8/0.5))).tolist()
X_real = np.linspace(0, 4.5, 20*(int(4.5/0.5))).tolist()
# X_real = X
X = X_real
# X=X_real

# delta0_4_real = [-0.1, -0.08224137750622422, -0.06445911931781168, -0.04673648447422905, -0.029165057356212578, -0.011840830549652969, 0.005141294248365311, 0.02168937355515034, 0.03771904092262235, 0.05315659325190492, 0.06794036133851503, 0.08202070864488743, 0.09536350329063843, 0.10794814350999217, 0.1197644696809841, 0.1308127436201251, 0.14110357613922883, 0.15065557180812347, 0.1594938908761832, 0.16764721326029916, 0.17514678927408, 0.18202643962785225, 0.1883225174081442, 0.1940717581805365, 0.19930849280324425, 0.20406588220644895, 0.2083760677392295, 0.2122701711695626, 0.21577829468432239, 0.2189295208892804, 0.2217519013671869, 0.2242705368682878, 0.2265063793329237, 0.2284791066189068, 0.23020723507800014, 0.23170811955591752, 0.23299795339232374, 0.2340917684208343, 0.23500343496901568, 0.23574555508935674, 0.23632816102175133, 0.2367595064712183, 0.2370472146849413, 0.23719829856622265, 0.23721916067448326, 0.23711559322526263, 0.236892778090219, 0.23655528679712903, 0.2361070805298882, 0.23555116266486434, 0.23488898903373578, 0.23412153452294782, 0.23324949554611718, 0.2322732900431778, 0.23119305748038071, 0.23000865885029417, 0.2287196766718036, 0.2273254149901115, 0.2258248993767377, 0.22421687692951897, 0.22250006380066212, 0.22067236097510473, 0.21873079222909694, 0.21667249042611147, 0.21449470625085462, 0.2121948082092656, 0.20977028262851732, 0.2072187336570158, 0.20453788326440026, 0.2017255712415432, 0.19877975520055075, 0.19569851057476173, 0.19248003061874894, 0.18912297747192372, 0.1856272693094487, 0.1819911900970087, 0.1782137185655415, 0.1742948732550899, 0.1702357125148018, 0.16603833450293018]
# omega_0_4_real = [38.39911, 38.40155995986925, 38.40091371023161, 38.39678561393208, 38.388935948825406, 38.377285350079475, 38.36191170035889, 38.34304450269052, 38.32104011555259, 38.296344643126446, 38.26946042503689, 38.24092827768071, 38.21128358834944, 38.18103189816954, 38.15062434369832, 38.12045738201352, 38.09087274218026, 38.06214594372259, 38.03447644076589, 38.008015879454945, 37.982872145608596, 37.959109364719765, 37.93674916262047, 37.915788789400146, 37.89619717721155, 37.877930877650165, 37.86093903081005, 37.84516336528384, 37.83053819816273, 37.81699043503648, 37.80443965496898, 37.79280930832392, 37.78203232876307, 37.77204222568873, 37.762774611653526, 37.75416720236045, 37.74615981666285, 37.738694376564446, 37.73171490721927, 37.72516818391746, 37.719009165255734, 37.713197981402026, 37.70769647769186, 37.70246817786173, 37.69747828404912, 37.69269367679246, 37.68808291503115, 37.68361623610558, 37.67926555575709, 37.675006134723304, 37.670817743048545, 37.66668104452029, 37.66257769266841, 37.658490330774036, 37.654402591869584, 37.65029909873872, 37.646165463916375, 37.641988289688754, 37.63775516809333, 37.633454680918824, 37.62907792346457, 37.62461822619577, 37.62006827780885, 37.61542249933603, 37.61067707521208, 37.6058299532743, 37.60088084476251, 37.595831224319035, 37.59068432998876, 37.58544516321908, 37.580120488859905, 37.574718835163694, 37.56925049378541, 37.56372738015534, 37.55816533094457, 37.552587037909966, 37.547017948339516, 37.54148589326505, 37.53602108746228, 37.5306561294508]

delta0_8_real = [-0.1, -0.08240861931558667, -0.06479330784534923, -0.04723486756264142, -0.029822178485714588, -0.012648517558398423, 0.004193769359367158, 0.020615070468403395, 0.03653279798978123, 0.05187451030266058, 0.06657932019673622, 0.08059787808531996, 0.09389539453760715, 0.10645070074680735, 0.11825273018780748, 0.12930045124053638, 0.1396028585981161, 0.14917708750742847, 0.1580467306505688, 0.16623925517427435, 0.1737846032854233, 0.18071519225103475, 0.18706591149261198, 0.19287278963333365, 0.19816958739912158, 0.20298875794918095, 0.2073617726781008, 0.21131912121585394, 0.21489031142779708, 0.21810386941467055, 0.22098733951259864, 0.2235663727056563, 0.22586207547339804, 0.22789389932981524, 0.22968018820308833, 0.2312381675958622, 0.23258394458524617, 0.233732507822814, 0.2346977275346038, 0.23549235017260245, 0.23612717670386432, 0.23661060631312783, 0.23695027515722764, 0.23715323168690508, 0.23722593664680838, 0.2371742630754924, 0.23700349630541886, 0.23671833396295622, 0.2363228859683797, 0.2358206077146069, 0.2352135223769131, 0.2345027116862261, 0.23368898114920303, 0.2327728681274681, 0.2317546418376125, 0.23063430335119428, 0.2294115855947388, 0.22808595334973822, 0.2266566032526517, 0.2251224637949055, 0.2234822383931581, 0.22173459056279846, 0.21987687441923603, 0.21790623671888287, 0.21581993766936908, 0.21361535092954265, 0.2112899636094696, 0.2088413762704338, 0.20626730292493725, 0.2035655710366996, 0.20073412152065903, 0.1977710087429711, 0.19467440052100926, 0.1914425781233659, 0.1880747683906338, 0.18457047580784894, 0.18092803703777757, 0.17714675243965355, 0.17322692361506864, 0.16916985340797233, 0.16497784590467188, 0.16065420643383216, 0.15620324156647603, 0.15163025911598413, 0.1469415681380948, 0.14214447893090398, 0.13724730303486576, 0.132259353232792, 0.12719094354985133, 0.12205214906089379, 0.11685097816613188, 0.11160462610113915, 0.10633137351873292, 0.10104942275428674, 0.09577689782573066, 0.0905318444335507, 0.08533222996078957, 0.08019594347304634, 0.07514079571847605, 0.07018451912779042, 0.06534476781425755, 0.060639117573701544, 0.056085065884503356, 0.0517000319075996, 0.047501356486483785, 0.043505416144083965, 0.039722543211094315, 0.036165649599452496, 0.03284681276196695, 0.0297761946831025, 0.026962041878980193, 0.024410685397377254, 0.02212654081772713, 0.020112108251119528, 0.01836797234030039, 0.016892802259671876, 0.015683351715292417, 0.014734458944876613, 0.014039996859498053, 0.013595399107829339, 0.01339290799106394, 0.0134237024659126, 0.013678170252357874, 0.014145907833654128, 0.014815720456327508, 0.01567562213017602, 0.01671283562826943, 0.017913792486949336, 0.019264133005829062, 0.020748706247793895, 0.022351570039000887, 0.024056058521801472, 0.025849695655320512, 0.02771949676078606, 0.02965053810059609, 0.03162850736844954, 0.033639703689346434, 0.03567103761958767, 0.037710031146775236, 0.03974481768981202, 0.041764142098901974, 0.04375736065555008, 0.04571444107256227, 0.04762596400225706, 0.049483929350185175, 0.05128071919413453, 0.05300875807892817, 0.05466128876087852, 0.05623237220778747, 0.057716887598946505, 0.05911053232513643, 0.06040982198862767, 0.06161209040318004, 0.06271548959404287, 0.0637189897979551, 0.06462237946314468, 0.06542626524932968, 0.06613108231518451, 0.06673675445206222, 0.06724442418580508, 0.06765558833619004, 0.06797209162670419, 0.06819612668454475, 0.06833023404061904, 0.06837730212954453, 0.06834056728964877, 0.0682236137629695, 0.0680303736952545, 0.06776512713596174, 0.06743250203825926, 0.06703747425902527, 0.06658536755884807, 0.06608090941176754, 0.06552670173951311, 0.06492780261789537, 0.06428936742983572, 0.06361642923759293, 0.06291389878276302, 0.06218656448627927, 0.06143909244841228, 0.06067602644876995, 0.05990178794629739, 0.05912067607927708, 0.058336867665328716, 0.057554417201409344, 0.05677725686381325, 0.05600919650817203, 0.05525392366945457, 0.0545150008887409, 0.053795081106952046, 0.053096898020559016, 0.05242356630522907, 0.051777898627531446
, 0.05116240564493739, 0.05057929600582016, 0.05003047634945495, 0.04951755130601901, 0.04904182349659156, 0.04860429353315381, 0.04820566001858902, 0.04784631954668232, 0.047526366702121015, 0.04724559406049424, 0.047003494811090965, 0.04679979701208145, 0.046634268118133586, 0.04650629929683243, 0.04641513798406913, 0.04635988788404094, 0.04633950896925122, 0.04635281748050946, 0.046398485926931216, 0.04647504308593817, 0.046580874003258096, 0.0467142199929249, 0.04687317863727857, 0.047055703786965206, 0.047259605560937015, 0.047482550346452296, 0.04772206079907548, 0.047975516258488435, 0.04824175590976177, 0.04851977045759607, 0.04880728241377241, 0.0491021173758502, 0.0494022040271672, 0.0497055741368395, 0.05001036255976153, 0.05031480723660606, 0.05061724919382421, 0.05091613254364542, 0.05121000448407748, 0.05149751529890652, 0.05177741835769699, 0.052048570115791684, 0.052309930114311745, 0.05256056098015667, 0.052799628426004275, 0.053026401250310704, 0.05324025293685294, 0.05344080616436125, 0.05362759221734415, 0.0538000861555572, 0.053957863361390294, 0.054100599539867684, 0.05422807071864802, 0.054340153248024284, 0.05443682380092385, 0.05451815937290842, 0.054584337282174114, 0.054635635169551375, 0.054672430998505016, 0.054695203055134214, 0.05470452994817255, 0.0547010906089879, 0.054685664291582566, 0.05465912506846746, 0.05462183578375033, 0.0545741756457722, 0.054516846209350905, 0.05445054913109094, 0.05437598616938347, 0.05429385918440633, 0.054204870138124014, 0.054109721094287695, 0.05400911421843521, 0.05390375177789105, 0.05379433614176638, 0.05368156978095903, 0.05356615526815352, 0.053448795277820975, 0.05333019258621926, 0.05321105007139285, 0.05309207071317293, 0.052973957593177315, 0.05285741389481051, 0.052743142903263665, 0.05263184800551463, 0.05252423269032788, 0.0524210005482546, 0.05232266266994518, 0.05222849913166289, 0.052138695715382634, 0.05205363509569546, 0.05197365277639179, 0.05189903709046142, 0.05183002920009348, 0.0517668230966765, 0.051709565600798334, 0.05165835636224624, 0.05161324786000681, 0.05157424540226602, 0.05154130712640919, 0.05151434399902102, 0.05149321981588556, 0.05147775120198624, 0.05146770761150585, 0.05146281132782652, 0.05146273746352978, 0.0514671139603965, 0.051475795670565476, 0.05148883728055751, 0.05150597518472322, 0.05152694115137951, 0.05155146497969697, 0.0515792744996998, 0.05161009557226583, 0.05164365208912655, 0.0516796659728671, 0.05171785717692622, 0.05175794368559633, 0.051799641514023456, 0.051842664708207295, 0.05188672534500116, 0.05193153353211201, 0.05197679740810044, 0.0520222231423807, 0.05206751493522066, 0.05211237501774183, 0.052156503651919386]
omega_0_8_real = [38.39911, 38.40155062752203, 38.400957001898, 38.39695234545143, 38.38930002392819, 38.37791780722099, 38.36287496086299, 38.344387538655226, 38.3227951422131, 38.29852704629487, 38.2720672871467, 38.24394057384525, 38.21466836964974, 38.184747283419256, 38.15462209123315, 38.124684917765094, 38.095275237468066, 38.06667217516875, 38.03907891054625, 38.012649852087264, 37.98749727103264, 37.96369130137734, 37.94126012801484, 37.920205173258594, 37.90050163252935, 37.882108863933816, 37.86497908897151, 37.849057392534704, 37.83428172290848, 37.82058289177068, 37.80788457419192, 37.7961088355298, 37.78518979586491, 37.77506231691277, 37.765663185922925, 37.75693121528892, 37.74880724254838, 37.741234130382956, 37.734156766618355, 37.72752214185816, 37.72128311741679, 37.715399924099096, 37.7098348522138, 37.70455180821833, 37.69951631471883, 37.694695510470126, 37.6900581503758, 37.685574605488114, 37.68121686300804, 37.676958909342524, 37.6727796102857, 37.66865983623189, 37.664581296553514, 37.66052665366418, 37.65647952301866, 37.652424473112895, 37.648347025484014, 37.64423365471031, 37.64007178841127, 37.63584980724753, 37.631557233978825, 37.62718721636928, 37.62273255609898, 37.61818683873076, 37.61354534782499, 37.608805064939595, 37.60396466963003, 37.599024539449296, 37.59398674994792, 37.588855074673994, 37.583634985173134, 37.5783336509885, 37.57295993966078, 37.567524416728226, 37.562039243433276, 37.55652216300489, 37.55099625431027, 37.54548692531208, 37.5400218793033, 37.534631114907185, 37.52934692607728, 37.52420390209741, 37.51923892758172, 37.514491182474615, 37.51000214205081, 37.50581557691529, 37.50197755300335, 37.49853643158056, 37.49554286924279, 37.49304302108728, 37.491059575699886, 37.48964691801789, 37.48885691393914, 37.48873327479356, 37.48931155734325, 37.49061916378239, 37.4926753417373, 37.49549118426642, 37.499069629860294, 37.50340546244161, 37.50848531136517, 37.51428765141789, 37.5207828028188, 37.52793293121908, 37.535692047702, 37.54400991324496, 37.55285096618827, 37.56215428081154, 37.57185407321635, 37.58188492885445, 37.59218180252783, 37.602680018388675, 37.61331526993937, 37.62402362003253, 37.63474150087097, 37.64540571400771, 37.65595343034598, 37.666322190139226, 37.676455259199486, 37.68631240328209, 37.69584159033799, 37.70499434030704, 37.7137274135451, 37.7220028108241, 37.729787773332, 37.73705478267279, 37.74378156086652, 37.749951070349276, 37.755551513973174, 37.76057633500638, 37.76502421713308, 37.76889895726538, 37.772199799606874, 37.774929442503996, 37.77709779746839, 37.77871743113852, 37.77980356527959, 37.78037407678364, 37.78044949766947, 37.780053015082686, 37.77921047129568, 37.77795036370761, 37.776303844844456, 37.774304706047225, 37.77197932253012, 37.76935380264216, 37.766460599457496, 37.76333113023461, 37.759995776416275, 37.756483883629585, 37.752823761685946, 37.749042684581056, 37.74516689049495, 37.74122158179195, 37.73723092502068, 37.73321805091412, 37.729205054389496, 37.72521072076488, 37.72125255932066, 37.71735020688987, 37.713521869335715, 37.709784302100026, 37.70615281020323, 37.70264124824437, 37.69926202040111, 37.6960260804297, 37.69294293166501, 37.69002062702053, 37.68726576898835, 37.68468350963916, 37.68227755062228, 37.68005014316562, 37.67800301588206, 37.67614060170409, 37.67446576512619, 37.67298029012575, 37.671685028902345, 37.6705799018778, 37.66966389769614, 37.6689350732236, 37.66839055354866, 37.668026531982, 37.66783827005652, 37.66782009752734, 37.66796541237179, 37.66826668078945, 37.668715437202074, 37.66930228425366, 37.67001690782583, 37.67085302173039, 37.67180416402816, 37.67286050370503, 37.67401225223242, 37.67524966356728, 37.67656303415208, 37.67794270291487, 37.67937905126919, 37.68086250311412, 37.6823835248343, 37.68393262529988, 37.68550035586655, 37.68707731037556, 37.68865412515364, 37.690221501296875, 37.69177369832435, 37.69330412523041, 37.69480420920397, 37.69626606690688, 37.69768250447391, 37.6990470175128, 37.700353791104185, 37.701597699801674, 37.70277430763178, 37.70387986809397, 37.70491132416065, 37.70586630827715, 37.706743142361745, 37.70754083780564, 37.70825909547298, 37.70889830570084, 37.709459548029784, 37.709943281642246, 37.710349344261246, 37.71067854174348, 37.71093199524275, 37.711111141209955, 37.71121773139305, 37.71125383283712, 37.71122182788432, 37.711124414173916, 37.710964604642236, 37.71074572752271, 37.71047142634589, 37.71014565993937, 37.70977270242787, 37.70935714323319, 37.70890388707422, 37.708418153966946, 37.70790547922444, 37.707371673205934, 37.70681778627549, 37.706245260831025, 37.70565837602426, 37.70506120452698, 37.7044576125311, 37.70385125974865, 37.70324559941179, 37.702643878272745, 37.70204913660392, 37.70146420819778, 37.70089172036693, 37.70033409394409, 37.699793543282084, 37.699272076253855, 37.69877149425246, 37.698293392191076, 37.69783913654523, 37.69740797178273, 37.69700042862474, 37.69661839604786, 37.69626352270417, 37.69593721692121, 37.69564064670197, 37.6953747397249, 37.69514018334391, 37.69493742458839, 37.69476667016316, 37.69462788644853, 37.69452079950024, 37.694444895049514, 37.69439941850303, 37.69438337494292, 37.69439552912678, 37.69443440548767, 37.694498288134106, 37.69458522085006, 37.69469300709497, 37.69481921000374, 37.694961152386725, 37.69511591672974, 37.695281131491335, 37.69545947388104, 37.69565017248209, 37.69585154672333, 37.69606197062381, 37.69627987279274, 37.69650373642957, 37.69673209932391, 37.696963553855575, 37.69719674699458, 37.69743038030112, 37.6976632099256, 37.69789404660861, 37.69812175568094, 37.69834525706356, 37.69856352526765, 37.69877558939458, 37.69898053313591, 37.699177494773394, 37.69936566717899, 37.6995447743465, 37.699714743259285, 37.69987487251584, 37.700024547127555, 37.70016324378896, 37.70029053087772, 37.700406068454676, 37.7005096082638, 37.70060099373221, 37.7006801599702, 37.700747133771166, 37.70080203361171, 37.70084506965154, 37.70087654373354, 37.70089684938372, 37.70090647181126, 37.70090598790848, 37.70089606625084, 37.70087746709697, 37.70085104238864]

# %%
delta0_4_real = delta0_8_real[0:180]
omega_0_4_real = omega_0_8_real[0:180]

# %%
# plt.figure()

# # plt.scatter(X,delta0_10,facecolors='none', edgecolors='r', label='True - del_t')
# # plt.plot(X, delta0_10, label=" Approximation delta")
# plt.scatter(X, delta0_4, label=" Approximation $\delta$")
# plt.plot(X_real, delta0_4_real, color='r',label=" Analytic $\delta$")

# # plt.scatter(X,pred_train_X, color='red',marker="x",s=4,label='Prediction - del_t')
# plt.xlabel('$t$',fontsize=16)
# plt.ylabel('$\delta$(t)',fontsize=16)
# plt.legend()
# plt.figure()
# # plt.plot(X[0:192], omega0_8, label=" Approximation omega")
# # plt.plot(X_real[0:192], omega_0_4_real[2:194], label=" Analytic omega")
# plt.scatter(X, omega0_4, label=" Approximation $\omega$")
# plt.plot(X_real, omega_0_4_real, color='r', label=" Analytic $\omega$")
# plt.legend()
# # plt.scatter(X,pred_train_X, color='red',marker="x",s=4,label='Prediction - del_t')
# plt.xlabel('$t$',fontsize=16)
# plt.ylabel('$\omega(t)$',fontsize=16)

# %%
#rescale
delta0_4_s = np.array(delta0_4_s)*10
delta0_4 = np.array(delta0_4)*10
delta0_4_real =np.array( delta0_4_real)*10
omega0_4_s = np.array(omega0_4_s)*10
omega0_4 = np.array(omega0_4)*10
omega_0_4_real = np.array(omega_0_4_real)*10

# %%
plt.figure()
font_size = 14
# plt.scatter(X,delta0_10,facecolors='none', edgecolors='r', label='True - del_t')
# plt.plot(X, delta0_10, label=" Approximation delta")
plt.scatter(X, delta0_4_s, label="SFQ $\delta$")
# plt.plot(X_real, delta0_4_real, color='g',label="Actual $\delta$")

# plt.scatter(X,pred_train_X, color='red',marker="x",s=4,label='Prediction - del_t')


plt.plot(X, delta0_4, 'r--',label="PFQ $\delta$")
plt.plot(X_real, delta0_4_real, color='g', label="Actual $\delta$")

plt.xlabel('$t$',fontsize=16)
plt.ylabel('$\delta$(t)',fontsize=16)
plt.legend(fontsize=font_size)
plt.figure()




# plt.plot(X[0:192], omega0_8, label=" Approximation omega")
# plt.plot(X_real[0:192], omega_0_4_real[2:194], label=" Analytic omega")
plt.scatter(X, omega0_4_s,label="SFQ $\omega$")

# plt.scatter(X,pred_train_X, color='red',marker="x",s=4,label='Prediction - del_t')
plt.xlabel('$t$',fontsize=16)
plt.ylabel('$\omega(t)$',fontsize=16)
# plt.figure()
# plt.plot(X[0:192], omega0_8, label=" Approximation omega")
# plt.plot(X_real[0:192], omega_0_4_real[2:194], label=" Analytic omega")
plt.plot(X, omega0_4, 'r--',label="PFQ $\omega$")
# plt.plot(X_real, omega_0_4_real, color='g', label="Actual $\omega$")
plt.plot(X_real, omega_0_4_real, color='g', label="Actual $\omega$")
plt.legend(fontsize=font_size)
# plt.scatter(X,pred_train_X, color='red',marker="x",s=4,label='Prediction - del_t')
plt.xlabel('$t$',fontsize=16)
plt.ylabel('$\omega(t)$',fontsize=16)
# Out:
# Text(0, 0.5, '$\\omega(t)$')

# %%
import pandas as pd

# Create a DataFrame
data = {
    'X': X,
    'delta0_4_s': delta0_4_s,
    'delta0_4': delta0_4,
    'delta0_4_real': delta0_4_real,
    'omega0_4_s': omega0_4_s,
    'omega0_4': omega0_4,
    'omega_0_4_real': omega_0_4_real
}

df = pd.DataFrame(data)

# Save DataFrame to CSV
df.to_csv('../data.csv', index=False)

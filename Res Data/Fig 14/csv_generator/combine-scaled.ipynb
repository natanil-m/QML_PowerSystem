# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def convertStrToArr(string_data):
    values = string_data.strip('[]').split()
    # return np.array([float(value) for value in values])
    return [float(value) for value in values]

# %%
#0-2
del1=[0.06284792217649898, 0.07093930393225674, 0.07881518598352669, 0.08647556833030887, 0.09392045097260326, 0.10114983391040988, 0.10816371714372872, 0.11496210067255976, 0.12154498449690304, 0.1279123686167585, 0.13406425303212618, 0.14000063774300614, 0.14572152274939829, 0.1512269080513026, 0.15651679364871923, 0.16159117954164798, 0.16645006573008891, 0.17109345221404218, 0.17552133899350764, 0.17973372606848528]
del2=[1.0571250336541347, 1.0442058682859205, 1.0314638387124668, 1.0188989449337733, 1.0065111869498402, 0.9943005647606673, 0.9822670783662548, 0.9704107277666026, 0.9587315129617108, 0.9472294339515792, 0.935904490736208, 0.9247566833155971, 0.9137860116897466, 0.9029924758586563, 0.8923760758223264, 0.8819368115807568, 0.8716746831339476, 0.8615896904818986, 0.8516818336246099, 0.8419511125620818]
del3=[0.9416185533939359, 0.9198979881591126, 0.8989203394179063, 0.8786856071703166, 0.8591937914163439, 0.8404448921559879, 0.8224389093892489, 0.8051758431161266, 0.788655693336621, 0.7728784600507322, 0.7578441432584603, 0.7435527429598052, 0.7300042591547669, 0.7171986918433453, 0.7051360410255407, 0.6938163067013527, 0.6832394888707819, 0.6734055875338275, 0.66431460269049, 0.6559665343407695]

omega1=[1.0002038990487565, 1.0002011838027036, 1.0001957533105974, 1.0001903228184912, 1.0001848923263852, 1.000179461834279, 1.0001740313421728, 1.0001686008500668, 1.0001631703579605, 1.0001577398658543, 1.0001523093737483, 1.000146878881642, 1.0001414483895361, 1.00013601789743, 1.0001305874053237, 1.0001251569132177, 1.0001197264211115, 1.0001142959290052, 1.0001088654368993, 1.0001061501908461]
omega2=[0.9996744430544964, 0.9996766749242278, 0.9996811386636907, 0.9996856024031536, 0.9996900661426165, 0.9996945298820794, 0.9996989936215422, 0.9997034573610051, 0.999707921100468, 0.9997123848399309, 0.9997168485793937, 0.9997213123188566, 0.9997257760583195, 0.9997302397977824, 0.9997347035372453, 0.9997391672767081, 0.999743631016171, 0.9997480947556339, 0.9997525584950968, 0.9997547903648282]
omega3=[0.9994526518802942, 0.9994620124549727, 0.9994807336043297, 0.9994994547536867, 0.9995181759030437, 0.9995368970524007, 0.9995556182017578, 0.9995743393511147, 0.9995930605004717, 0.9996117816498287, 0.9996305027991857, 0.9996492239485427, 0.9996679450978997, 0.9996866662472567, 0.9997053873966137, 0.9997241085459707, 0.9997428296953277, 0.9997615508446847, 0.9997802719940417, 0.9997896325687202]

# %%
#2-4
del1.extend([0.1798172049695484, 0.18386148119486684, 0.18778914787397183, 0.1916002050068632, 0.19529465259354117, 0.19887249063400567, 0.20233371912825665, 0.2056783380762941, 0.20890634747811804, 0.21201774733372852, 0.2150125376431254, 0.21789071840630886, 0.22065228962327876, 0.22329725129403527, 0.22582560341857827, 0.22823734599690776, 0.23053247902902374, 0.23271100251492616, 0.23477291645461507, 0.2367182208480904])
del2.extend([0.8419039860310509, 0.8332357835026786, 0.8247690259834021, 0.8165037134732219, 0.8084398459721379, 0.80057742348015, 0.7929164459972582, 0.7854569135234627, 0.7781988260587631, 0.7711421836031599, 0.7642869861566528, 0.757633233719242, 0.751180926290927, 0.7449300638717087, 0.738880646461586, 0.7330326740605595, 0.7273861466686298, 0.7219410642857955, 0.7166974269120574, 0.7116552345474156])
del3.extend([0.6540457552631609, 0.6465328077107835, 0.6392483335863848, 0.632192332889965, 0.6253648056215242, 0.6187657517810625, 0.6123951713685796, 0.6062530643840757, 0.6003394308275509, 0.594654270699005, 0.5891975839984378, 0.5839693707258501, 0.5789696308812406, 0.5741983644646107, 0.5696555714759595, 0.5653412519152873, 0.561255405782594, 0.5573980330778803, 0.5537691338011448, 0.550368707952388])
omega1.extend([1.0001019138757932, 1.0001004446226873, 1.0000975061164759, 1.0000945676102644, 1.000091629104053, 1.0000886905978414, 1.00008575209163, 1.0000828135854185, 1.000079875079207, 1.0000769365729953, 1.0000739980667839, 1.0000710595605724, 1.000068121054361, 1.0000651825481495, 1.000062244041938, 1.0000593055357265, 1.000056367029515, 1.0000534285233036, 1.000050490017092, 1.0000490207639863])
omega2.extend([0.9997815653366365, 0.9997841034968031, 0.9997891798171364, 0.9997942561374699, 0.9997993324578032, 0.9998044087781365, 0.9998094850984698, 0.9998145614188031, 0.9998196377391364, 0.9998247140594698, 0.9998297903798031, 0.9998348667001364, 0.9998399430204697, 0.999845019340803, 0.9998500956611364, 0.9998551719814698, 0.9998602483018031, 0.9998653246221364, 0.9998704009424697, 0.9998729391026364])
omega3.extend([0.9998106772235535, 0.999813555935499, 0.99981931335939, 0.9998250707832809, 0.9998308282071717, 0.9998365856310627, 0.9998423430549536, 0.9998481004788445, 0.9998538579027354, 0.9998596153266263, 0.9998653727505172, 0.9998711301744081, 0.9998768875982991, 0.9998826450221899, 0.9998884024460809, 0.9998941598699718, 0.9998999172938627, 0.9999056747177536, 0.9999114321416445, 0.99991431085359])

#4-6
del1.extend([0.2368487357715383, 0.23873011688803414, 0.24055591968135748, 0.24232614415150822, 0.24404079029848644, 0.24569985812229234, 0.24730334762292547, 0.2488512588003862, 0.25034359165467446, 0.25178034618579004, 0.253161522393733, 0.2544871202785038, 0.25575713984010173, 0.25697158107852713, 0.25813044399378027, 0.25923372858586075, 0.26028143485476873, 0.2612735628005041, 0.26221011242306697, 0.26309108372245715])
del2.extend([0.7111794460218475, 0.7066619837558341, 0.7022645507212667, 0.6979871469181455, 0.6938297723464706, 0.6897924270062414, 0.6858751108974587, 0.6820778240201217, 0.6784005663742312, 0.6748433379597865, 0.6714061387767878, 0.6680889688252356, 0.6648918281051293, 0.661814716616469, 0.6588576343592548, 0.6560205813334866, 0.6533035575391646, 0.6507065629762887, 0.6482295976448589, 0.6458726615448755])
del3.extend([0.5499678156347011, 0.5469263057375906, 0.5439783147407677, 0.5411238426442317, 0.538362889447983, 0.5356954551520214, 0.5331215397563474, 0.5306411432609598, 0.5282542656658602, 0.5259609069710472, 0.5237610671765216, 0.5216547462822831, 0.5196419442883322, 0.5177226611946683, 0.515896897001291, 0.5141646517082016, 0.5125259253153991, 0.5109807178228838, 0.5095290292306557, 0.5081708595387149])
omega1.extend([1.0000474099272016, 1.0000467096532826, 1.0000453091054444, 1.0000439085576063, 1.000042508009768, 1.0000411074619298, 1.0000397069140914, 1.0000383063662532, 1.000036905818415, 1.0000355052705767, 1.0000341047227386, 1.0000327041749002, 1.000031303627062, 1.000029903079224, 1.0000285025313855, 1.0000271019835474, 1.000025701435709, 1.0000243008878709, 1.0000229003400327, 1.0000222000661134])
omega2.extend([0.9998861620565389, 0.9998876743968816, 0.999890699077567, 0.9998937237582525, 0.9998967484389378, 0.9998997731196232, 0.9999027978003087, 0.999905822480994, 0.9999088471616794, 0.9999118718423649, 0.9999148965230502, 0.9999179212037357, 0.999920945884421, 0.9999239705651064, 0.9999269952457919, 0.9999300199264772, 0.9999330446071626, 0.9999360692878481, 0.9999390939685334, 0.9999406063088762])
omega3.extend([0.9999233553682765, 0.999924533684625, 0.999926890317322, 0.999929246950019, 0.9999316035827159, 0.9999339602154128, 0.9999363168481098, 0.9999386734808068, 0.9999410301135038, 0.9999433867462008, 0.9999457433788977, 0.9999481000115947, 0.9999504566442917, 0.9999528132769886, 0.9999551699096856, 0.9999575265423826, 0.9999598831750796, 0.9999622398077765, 0.9999645964404735, 0.999965774756822])
#6-8
del1.extend([0.26318463395361086, 0.2640385772300113, 0.26486713681441765, 0.2656703127068303, 0.26644810490724935, 0.2672005134156745, 0.267927538232106, 0.2686291793565437, 0.2693054367889876, 0.2699563105294375, 0.27058180057789405, 0.27118190693435645, 0.2717566295988254, 0.2723059685713004, 0.2728299238517818, 0.27332849544026927, 0.2738016833367632, 0.274249487541263, 0.27467190805376923, 0.2750689448742818])
del2.extend([0.6457174827331782, 0.6435344304260494, 0.6414153023535061, 0.6393600985155489, 0.6373688189121777, 0.6354414635433926, 0.6335780324091934, 0.6317785255095801, 0.6300429428445524, 0.6283712844141108, 0.6267635502182561, 0.625219740256987, 0.6237398545303041, 0.6223238930382068, 0.6209718557806954, 0.6196837427577704, 0.6184595539694309, 0.6172992894156777, 0.6162029490965104, 0.6151705330119293])
del3.extend([0.5079737252290298, 0.5066331989750821, 0.5053352801024779, 0.5040799686112173, 0.5028672645013005, 0.5016971677727274, 0.5005696784254979, 0.49948479645961213, 0.4984425218750698, 0.4974428546718713, 0.4964857948500164, 0.49557134240950523, 0.4946994973503378, 0.4938702596725136, 0.49308362937603367, 0.49233960646089725, 0.491638190927104, 0.4909793827746549, 0.49036318200354934, 0.4897895886137881])
omega1.extend([1.0000215189725323, 1.000021199143929, 1.0000205594867224, 1.0000199198295157, 1.0000192801723091, 1.0000186405151026, 1.0000180008578958, 1.0000173612006893, 1.0000167215434828, 1.0000160818862762, 1.0000154422290695, 1.000014802571863, 1.0000141629146564, 1.0000135232574496, 1.000012883600243, 1.0000122439430366, 1.0000116042858298, 1.0000109646286233, 1.0000103249714167, 1.0000100051428134])
omega2.extend([0.9999449880994068, 0.9999457935298647, 0.9999474043907803, 0.9999490152516961, 0.9999506261126119, 0.9999522369735275, 0.9999538478344433, 0.999955458695359, 0.9999570695562747, 0.9999586804171905, 0.9999602912781062, 0.9999619021390219, 0.9999635129999377, 0.9999651238608533, 0.9999667347217691, 0.9999683455826849, 0.9999699564436005, 0.9999715673045163, 0.999973178165432, 0.9999739835958898])
omega3.extend([0.9999662193632356, 0.9999667562063107, 0.9999678298924607, 0.9999689035786108, 0.9999699772647608, 0.9999710509509109, 0.999972124637061, 0.999973198323211, 0.9999742720093611, 0.999975345695511, 0.9999764193816612, 0.9999774930678113, 0.9999785667539612, 0.9999796404401113, 0.9999807141262614, 0.9999817878124114, 0.9999828614985615, 0.9999839351847115, 0.9999850088708616, 0.9999855457139367])
#8-10
del1.extend([0.2751184312687823, 0.2755096159819794, 0.2758889236082539, 0.27625635414760574, 0.2766119076000352, 0.27695558396554204, 0.2772873832441263, 0.27760730543578804, 0.2779153505405272, 0.2782115185583438, 0.278495809489238, 0.2787682233332095, 0.27902876009025834, 0.27927741976038484, 0.2795142023435887, 0.27973910783987016, 0.27995213624922877, 0.2801532875716652, 0.28034256180717887, 0.28051995895576987])
del2.extend([0.6149544919453749, 0.6139955641597739, 0.6130627486775038, 0.6121560454985642, 0.6112754546229557, 0.6104209760506785, 0.6095926097817317, 0.6087903558161155, 0.6080142141538312, 0.607264184794877, 0.6065402677392543, 0.6058424629869616, 0.6051707705380003, 0.6045251903923697, 0.6039057225500707, 0.6033123670111017, 0.6027451237754637, 0.6022039928431571, 0.6016889742141807, 0.6012000678885357])
del3.extend([0.48912198887180713, 0.4888092311199354, 0.4884848163309714, 0.48814874450491524, 0.48780101564176687, 0.48744162974152616, 0.4870705868041934, 0.4866878868297683, 0.4862935298182509, 0.48588751576964145, 0.4854698446839397, 0.4850405165611456, 0.48459953140125944, 0.48414688920428106, 0.48368258997021035, 0.4832066336990474, 0.4827190203907924, 0.48221975004544504, 0.4817088226630056, 0.48118623824347373])
omega1.extend([1.0000098576724368, 1.0000097080239096, 1.0000094087268552, 1.0000091094298007, 1.0000088101327465, 1.000008510835692, 1.0000082115386375, 1.0000079122415833, 1.0000076129445288, 1.0000073136474743, 1.00000701435042, 1.0000067150533656, 1.000006415756311, 1.0000061164592569, 1.0000058171622024, 1.000005517865148, 1.0000052185680937, 1.0000049192710392, 1.0000046199739847, 1.0000044703254576])
omega2.extend([0.9999758354667704, 0.9999761644757068, 0.9999768224935794, 0.9999774805114521, 0.9999781385293248, 0.9999787965471975, 0.9999794545650702, 0.9999801125829428, 0.9999807706008156, 0.9999814286186882, 0.999982086636561, 0.9999827446544336, 0.9999834026723063, 0.999984060690179, 0.9999847187080516, 0.9999853767259244, 0.999986034743797, 0.9999866927616697, 0.9999873507795424, 0.9999876797884788])
omega3.extend([0.9999921186504329, 0.9999919717744823, 0.999991678022581, 0.9999913842706798, 0.9999910905187785, 0.9999907967668773, 0.999990503014976, 0.9999902092630748, 0.9999899155111736, 0.9999896217592723, 0.9999893280073712, 0.9999890342554699, 0.9999887405035687, 0.9999884467516674, 0.9999881529997662, 0.9999878592478649, 0.9999875654959637, 0.9999872717440624, 0.9999869779921612, 0.9999868311162106])
#10-10.083
del1.extend([0.2804986713756734, 0.28050191355666476, 0.28050515718102936, 0.2805084022487673, 0.28051164875987844, 0.2805148967143629, 0.28051814611222065, 0.28052139695345163, 0.2805246492380559, 0.2805279029660335, 0.28053115813738433, 0.2805344147521085, 0.28053767281020586, 0.2805409323116766, 0.2805441932565205, 0.28054745564473776, 0.2805507194763283, 0.2805539847512921, 0.2805572514696292, 0.28056051963133954])
del2.extend([0.6011130306044056, 0.6022104433742196, 0.6033083320034677, 0.6044066964921498, 0.6055055368402663, 0.6066048530478166, 0.6077046451148015, 0.6088049130412202, 0.6099056568270734, 0.611006876472361, 0.6121085719770826, 0.6132107433412383, 0.6143133905648283, 0.6154165136478525, 0.6165201125903109, 0.6176241873922029, 0.6187287380535299, 0.6198337645742907, 0.6209392669544859, 0.6220452451941149])
del3.extend([0.48176131141999207, 0.48238902640475195, 0.4830169182020984, 0.48364498681203, 0.48427323223454927, 0.4849016544696531, 0.48553025351734286, 0.4861590293776185, 0.48678798205048085, 0.48741711153592776, 0.48804641783396113, 0.4886759009445805, 0.48930556086778626, 0.48993539760357735, 0.49056541115195446, 0.49119560151291713, 0.49182596868646716, 0.4924565126726011, 0.4930872334713216, 0.49371813108262846])
omega1.extend([1.0000019687096329, 1.0000019691478537, 1.0000019700242955, 1.0000019709007373, 1.000001971777179, 1.000001972653621, 1.0000019735300627, 1.0000019744065043, 1.000001975282946, 1.000001976159388, 1.0000019770358297, 1.0000019779122715, 1.0000019787887133, 1.0000019796651551, 1.000001980541597, 1.0000019814180388, 1.0000019822944803, 1.0000019831709221, 1.000001984047364, 1.000001984485585])
omega2.extend([1.0006663684405366, 1.0006665129156684, 1.000666801865932, 1.0006670908161954, 1.0006673797664591, 1.0006676687167226, 1.0006679576669861, 1.0006682466172496, 1.0006685355675133, 1.000668824517777, 1.0006691134680405, 1.0006694024183038, 1.0006696913685675, 1.0006699803188313, 1.0006702692690945, 1.0006705582193582, 1.0006708471696217, 1.0006711361198855, 1.000671425070149, 1.0006715695452804])
omega3.extend([1.0003811596392913, 1.000381213321156, 1.0003813206848848, 1.000381428048614, 1.000381535412343, 1.0003816427760717, 1.0003817501398007, 1.0003818575035297, 1.0003819648672585, 1.0003820722309873, 1.0003821795947163, 1.0003822869584453, 1.0003823943221744, 1.0003825016859031, 1.000382609049632, 1.0003827164133612, 1.00038282377709, 1.0003829311408186, 1.0003830385045478, 1.0003830921864123])
#10.083-12
del1.extend([0.27935814166710615, 0.2783156964948572, 0.2772952762505183, 0.27629688093408933, 0.2753205105455714, 0.2743661650849635, 0.27343384455226616, 0.2725235489474793, 0.27163527827060263, 0.2707690325216372, 0.26992481170058125, 0.26910261580743583, 0.268302444842201, 0.2675242988048775, 0.2667681776954629, 0.26603408151395935, 0.26532201026036595, 0.26463196393468347, 0.26396394253691186, 0.2633179460670498])
del2.extend([0.6237948262397419, 0.6295260729030092, 0.6353187746784739, 0.6411729315661363, 0.6470885435659962, 0.6530656106780537, 0.6591041329023088, 0.6652041102387617, 0.6713655426874121, 0.67758843024826, 0.6838727729213054, 0.6902185707065487, 0.6966258236039895, 0.7030945316136278, 0.7096246947354639, 0.7162163129694972, 0.7228693863157285, 0.7295839147741573, 0.7363598983447834, 0.7431973370276078])
del3.extend([0.5025909080448381, 0.5186511548332584, 0.5341653004183637, 0.5491333448001212, 0.5635552879785468, 0.5774311299536432, 0.5907608707254024, 0.60354451029382, 0.6157820486589118, 0.6274734858206683, 0.6386188217790982, 0.6492180565341927, 0.6592711900859545, 0.6687782224343666, 0.6777391535794584, 0.6861539835212183, 0.6940227122596347, 0.7013453397947167, 0.7081218661264801, 0.7143522912549072])
omega1.extend([0.9999725934977103, 0.9999728830219238, 0.9999734620703508, 0.9999740411187777, 0.9999746201672047, 0.9999751992156317, 0.9999757782640587, 0.9999763573124857, 0.9999769363609127, 0.9999775154093397, 0.9999780944577666, 0.9999786735061936, 0.9999792525546206, 0.9999798316030476, 0.9999804106514746, 0.9999809896999016, 0.9999815687483286, 0.9999821477967555, 0.9999827268451825, 0.999983016369396])
omega2.extend([1.0001506778763825, 1.0001514857220697, 1.0001531014134442, 1.0001547171048186, 1.000156332796193, 1.0001579484875676, 1.000159564178942, 1.0001611798703165, 1.000162795561691, 1.0001644112530654, 1.00016602694444, 1.0001676426358144, 1.0001692583271888, 1.0001708740185633, 1.0001724897099378, 1.0001741054013122, 1.0001757210926867, 1.0001773367840612, 1.0001789524754356, 1.0001797603211229])
omega3.extend([1.0004222334201331, 1.0004150547577548, 1.0004006974329978, 1.0003863401082402, 1.0003719827834832, 1.0003576254587259, 1.0003432681339686, 1.0003289108092113, 1.0003145534844542, 1.0003001961596971, 1.0002858388349398, 1.0002714815101827, 1.0002571241854252, 1.000242766860668, 1.000228409535911, 1.0002140522111538, 1.0001996948863963, 1.0001853375616392, 1.0001709802368823, 1.0001638015745036])

#12-14
del1.extend([0.2644230753437129, 0.264456957777889, 0.26453724397124645, 0.26466393392378373, 0.2648370276355032, 0.26505652510640243, 0.2653224263364838, 0.26563473132574456, 0.2659934400741879, 0.26639855258181133, 0.2668500688486153, 0.267347988874602, 0.2678923126597681, 0.26848304020411495, 0.26912017150764334, 0.26980370657035313, 0.2705336453922433, 0.2713099879733142, 0.27213273431356605, 0.273001884412999])
del2.extend([0.754271459108135, 0.7619223854799644, 0.7694523691971702, 0.7768614102597566, 0.7841495086677144, 0.7913166644210523, 0.798362877519766, 0.8052881479638623, 0.8120924757533314, 0.8187758608881803, 0.8253383033684045, 0.8317798031940016, 0.838100360364979, 0.844299974881334, 0.8503786467430672, 0.8563363759501772, 0.8621731625026603, 0.867889006400528, 0.8734839076437653, 0.8789578662323845])
del3.extend([0.7400309098699474, 0.7467791922060794, 0.753492394519886, 0.7601705168113654, 0.7668135590805234, 0.7734215213273509, 0.7799944035518569, 0.7865322057540324, 0.7930349279338849, 0.799502570091413, 0.8059351322266148, 0.8123326143394862, 0.8186950164300295, 0.8250223384982556, 0.8313145805441533, 0.8375717425677232, 0.8437938245689693, 0.8499808265478866, 0.8561327485044863, 0.8622495904387502])
omega1.extend([1.0000008907893043, 1.0000015007804897, 1.00000272076286, 1.0000039407452304, 1.0000051607276008, 1.000006380709971, 1.0000076006923415, 1.000008820674712, 1.0000100406570822, 1.0000112606394527, 1.0000124806218231, 1.0000137006041936, 1.0000149205865638, 1.0000161405689343, 1.0000173605513047, 1.000018580533675, 1.0000198005160454, 1.000021020498416, 1.0000222404807861, 1.0000228504719715])
omega2.extend([1.0002011473952874, 1.0001995575682014, 1.0001963779140297, 1.000193198259858, 1.000190018605686, 1.0001868389515143, 1.0001836592973425, 1.0001804796431706, 1.0001772999889988, 1.0001741203348269, 1.0001709406806552, 1.0001677610264832, 1.0001645813723115, 1.0001614017181397, 1.0001582220639678, 1.000155042409796, 1.000151862755624, 1.0001486831014523, 1.0001455034472804, 1.0001439136201946])
omega3.extend([1.0001774163478523, 1.0001769552105486, 1.000176032935941, 1.0001751106613335, 1.0001741883867257, 1.000173266112118, 1.0001723438375105, 1.000171421562903, 1.0001704992882954, 1.0001695770136878, 1.00016865473908, 1.0001677324644724, 1.0001668101898649, 1.0001658879152573, 1.0001649656406495, 1.000164043366042, 1.0001631210914343, 1.0001621988168268, 1.0001612765422192, 1.0001608154049153])

#14-16
del1.extend([0.2735450845501945, 0.27468068832319753, 0.27582526926511747, 0.27697882737595425, 0.2781413626557079, 0.2793128751043783, 0.2804933647219656, 0.28168283150846984, 0.2828812754638909, 0.2840886965882288, 0.28530509488148353, 0.2865304703436552, 0.2877648229747436, 0.2890081527747489, 0.2902604597436711, 0.2915217438815102, 0.29279200518826604, 0.2940712436639388, 0.29535945930852836, 0.29665665212203485])
del2.extend([0.8878891965758613, 0.8927585629776227, 0.8976666331846085, 0.9026134071968186, 0.9075988850142527, 0.9126230666369113, 0.9176859520647941, 0.9227875412979011, 0.9279278343362324, 0.9331068311797881, 0.9383245318285679, 0.9435809362825722, 0.9488760445418005, 0.9542098566062532, 0.95958237247593, 0.9649935921508315, 0.9704435156309569, 0.9759321429163068, 0.9814594740068808, 0.9870255089026791])
del3.extend([0.868953779681791, 0.8727201119202163, 0.8764749794116693, 0.8802183821561472, 0.883950320153651, 0.8876707934041824, 0.8913798019077382, 0.895077345664321, 0.8987634246739288, 0.902438038936563, 0.9061011884522243, 0.9097528732209111, 0.9133930932426213, 0.917021848517361, 0.9206391390451246, 0.9242449648259142, 0.92783932585973, 0.9314222221465748, 0.9349936536864413, 0.938553620479335])
omega1.extend([1.0000286166857613, 1.0000287297959976, 1.00002895601647, 1.0000291822369423, 1.0000294084574146, 1.000029634677887, 1.0000298608983593, 1.0000300871188317, 1.0000303133393038, 1.0000305395597762, 1.0000307657802485, 1.0000309920007209, 1.0000312182211932, 1.0000314444416656, 1.000031670662138, 1.0000318968826103, 1.0000321231030826, 1.000032349323555, 1.0000325755440274, 1.0000326886542634])
omega2.extend([1.0001227057636553, 1.000123193422581, 1.0001241687404323, 1.0001251440582837, 1.000126119376135, 1.0001270946939864, 1.0001280700118378, 1.000129045329689, 1.0001300206475403, 1.0001309959653917, 1.000131971283243, 1.0001329466010944, 1.0001339219189458, 1.0001348972367972, 1.0001358725546485, 1.0001368478725, 1.0001378231903513, 1.0001387985082026, 1.0001397738260538, 1.0001402614849795])
omega3.extend([1.0000949098168763, 1.0000947653637364, 1.0000944764574566, 1.0000941875511766, 1.0000938986448968, 1.000093609738617, 1.000093320832337, 1.0000930319260573, 1.0000927430197772, 1.0000924541134975, 1.0000921652072174, 1.0000918763009377, 1.0000915873946576, 1.0000912984883779, 1.0000910095820978, 1.000090720675818, 1.0000904317695383, 1.0000901428632583, 1.0000898539569782, 1.0000897095038384])

#16-18
del1.extend([0.29708076628771984, 0.2985867605668404, 0.30010307020452004, 0.30162969520075866, 0.3031666355555564, 0.304713891268913, 0.3062714623408287, 0.30783934877130337, 0.3094175505603371, 0.3110060677079298, 0.3126049002140816, 0.3142140480787924, 0.31583351130206216, 0.317463289883891, 0.31910338382427883, 0.32075379312322566, 0.3224145177807316, 0.3240855577967965, 0.3257669131714203, 0.32745858390460325])
del2.extend([0.9911539283247723, 0.9951125904073477, 0.9990984818557819, 1.0031116026700753, 1.007151952850228, 1.0112195323962399, 1.0153143413081105, 1.0194363795858403, 1.0235856472294294, 1.0277621442388776, 1.0319658706141848, 1.0361968263553512, 1.0404550114623765, 1.044740425935261, 1.0490530697740048, 1.0533929429786075, 1.0577600455490694, 1.0621543774853903, 1.0665759387875706, 1.0710247294556097])
del3.extend([0.9433353447221633, 0.946128315873674, 0.9489077569760074, 0.9516736680291704, 0.9544260490331535, 0.9571648999879638, 0.9598902208936004, 0.9626020117500589, 0.9653002725573452, 0.9679850033154558, 0.9706562040243918, 0.973313874684153, 0.9759580152947385, 0.9785886258561494, 0.9812057063683879, 0.9838092568314469, 0.9863992772453327, 0.9889757676100446, 0.9915387279255827, 0.994088158191945])
omega1.extend([1.000037950353872, 1.000038080324986, 1.0000383402672135, 1.000038600209441, 1.0000388601516688, 1.0000391200938963, 1.0000393800361238, 1.0000396399783513, 1.000039899920579, 1.0000401598628066, 1.000040419805034, 1.0000406797472616, 1.0000409396894894, 1.000041199631717, 1.0000414595739444, 1.000041719516172, 1.0000419794583997, 1.0000422394006272, 1.0000424993428547, 1.0000426293139686])
omega2.extend([1.0000997564393017, 1.0001000995229656, 1.0001007856902933, 1.000101471857621, 1.0001021580249487, 1.0001028441922766, 1.0001035303596042, 1.000104216526932, 1.0001049026942597, 1.0001055888615875, 1.0001062750289151, 1.0001069611962428, 1.0001076473635706, 1.0001083335308982, 1.000109019698226, 1.0001097058655537, 1.0001103920328815, 1.0001110782002092, 1.000111764367537, 1.0001121074512007])
omega3.extend([1.0000703815711813, 1.000070211095715, 1.0000698701447823, 1.0000695291938495, 1.0000691882429167, 1.000068847291984, 1.0000685063410515, 1.0000681653901187, 1.000067824439186, 1.0000674834882533, 1.0000671425373207, 1.000066801586388, 1.0000664606354552, 1.0000661196845226, 1.0000657787335898, 1.0000654377826572, 1.0000650968317246, 1.0000647558807918, 1.0000644149298592, 1.0000642444543928])

#18-20
del1.extend([0.3276995218349717, 0.3293872238659572, 0.33108514540697087, 0.33279328645801254, 0.33451164701908254, 0.3362402270901803, 0.3379790266713063, 0.3397280457624604, 0.3414872843636425, 0.3432567424748528, 0.34503642009609115, 0.34682631722735763, 0.3486264338686521, 0.35043677001997475, 0.3522573256813254, 0.3540881008527042, 0.3559290955341111, 0.35778030972554603, 0.35964174342700916, 0.36151339663850024])
del2.extend([1.0720780731714739, 1.075285594653272, 1.0785115369415652, 1.0817559000363537, 1.085018683937637, 1.0882998886454154, 1.091599514159689, 1.0949175604804573, 1.0982540276077208, 1.1016089155414797, 1.1049822242817335, 1.1083739538284823, 1.1117841041817262, 1.115212675341465, 1.118659667307699, 1.122125080080428, 1.1256089136596523, 1.1291111680453714, 1.1326318432375857, 1.1361709392362949])
del3.extend([0.9939896818464198, 0.9962126818959136, 0.9984232280600209, 1.0006213203387413, 1.0028069587320754, 1.0049801432400216, 1.0071408738625818, 1.0092891505997557, 1.01142497345154, 1.0135483424179408, 1.0156592574989518, 1.017757718694576, 1.0198437260048143, 1.0219172794296651, 1.0239783789691286, 1.026027024623205, 1.0280632163918957, 1.0300869542752003, 1.0320982382731176, 1.0340970683856439])
omega1.extend([1.000042529304523, 1.0000426580679675, 1.000042915594857, 1.0000431731217463, 1.0000434306486354, 1.0000436881755248, 1.000043945702414, 1.0000442032293033, 1.0000444607561925, 1.0000447182830818, 1.0000449758099712, 1.0000452333368604, 1.0000454908637497, 1.0000457483906389, 1.0000460059175282, 1.0000462634444174, 1.0000465209713068, 1.0000467784981961, 1.0000470360250853, 1.0000471647885298])
omega2.extend([1.0000808280462776, 1.0000810601441465, 1.000081524339884, 1.0000819885356216, 1.000082452731359, 1.0000829169270966, 1.000083381122834, 1.0000838453185716, 1.000084309514309, 1.0000847737100467, 1.000085237905784, 1.0000857021015217, 1.000086166297259, 1.0000866304929967, 1.0000870946887341, 1.0000875588844718, 1.0000880230802092, 1.0000884872759468, 1.0000889514716844, 1.0000891835695531])
omega3.extend([1.0000560185650806, 1.0000558616490274, 1.0000555478169204, 1.0000552339848137, 1.0000549201527067, 1.0000546063206, 1.000054292488493, 1.0000539786563862, 1.0000536648242793, 1.0000533509921725, 1.0000530371600655, 1.0000527233279588, 1.000052409495852, 1.000052095663745, 1.0000517818316383, 1.0000514679995314, 1.0000511541674246, 1.0000508403353177, 1.000050526503211, 1.0000503695871574])

# %%
print(len(del1))
print(len(omega1))
# Out:
# 220
# 220

# %%
#0-10
del1_target_values=[0.0626, 0.07011511700126488, 0.07781808464088463, 0.08528731252235024, 0.09252561232632919, 0.09953627253483219, 0.10632298558469415, 0.11288978592381416, 0.11924099550094004, 0.12538116092310436, 0.1313150214749864, 0.13704746128002537, 0.14258346593202448, 0.1479280980321741, 0.15308647180975246, 0.1580637231704054, 0.162864979448481, 0.16749535092036527, 0.17195992276795335, 0.17626372398609969, 0.18041172093460003, 0.18440880330416648, 0.18825978411642774, 0.19196939929507387, 0.19554228187986128, 0.19898296573960586, 0.20229588029414014, 0.20548535048126088, 0.20855559682179, 0.21151074046976706, 0.2143547838168953, 0.2170916139850914, 0.2197250100699584, 0.22225864314078608, 0.22469607624055052, 0.22704076402879042, 0.2292960674376365, 0.23146523256816745, 0.2335513914684538, 0.2355575804690473, 0.23748674018298058, 0.2393417155057674, 0.24112525561540263, 0.24284001373755157, 0.244488560938238, 0.24607339087230434, 0.24759687898979374, 0.2490613254879243, 0.2504689553110891, 0.2518219181508561, 0.25312228844596824, 0.25437206538234336, 0.2555731728930744, 0.2567274565279365, 0.2578367318859555, 0.25890272387293733, 0.25992707556876277, 0.2609113770204691, 0.26185716524225067, 0.26276592421545836, 0.2636390848885999, 0.26447802517733987, 0.2652840699644995, 0.2660584911000569, 0.26680250740114697, 0.26751729059635415, 0.2682040204583055, 0.2688637690148282, 0.2694975720362532, 0.27010643179502225, 0.2706913170656882, 0.2712531631249151, 0.2717928717514777, 0.272311311226262, 0.27280931633226513, 0.2732876883545949, 0.27374719508047035, 0.27418857079922165, 0.2746125101242157, 0.27501972051752316, 0.2754108805347162, 0.27578660364113317, 0.27614748446390364, 0.2764940987919484, 0.27682700357597934, 0.2771467369284995, 0.27745381812380304, 0.2777487475979754, 0.278032006948893, 0.2783040589362236, 0.27856534748142603, 0.2788162976677502, 0.2790573157402372, 0.2792887891057194, 0.27951108737321, 0.2797245928018323, 0.27992964027298156, 0.28012656335770103, 0.28031568295253395, 0.2804973072795233]
omega1_target_values=[1.0, 1.0002053744712585, 1.0001992040515397, 1.0001931005995672, 1.0001870775646282, 1.0001811464936181, 1.0001753170129084, 1.0001695977322709, 1.000163994917078, 1.0001585142393608, 1.00015316022813, 1.0001479358015117, 1.0001428435604998, 1.000137885066431, 1.0001330611039434, 1.0001283720239111, 1.0001238177119913, 1.000119397078641, 1.0001151093429679, 1.0001109527154783, 1.000106925821476, 1.0001030266044477, 1.0000992523260634, 1.0000956012128968, 1.0000920702602558, 1.0000886572139727, 1.00008535944865, 1.000082173958235, 1.0000790974204912, 1.000076127696918, 1.00007326140231, 1.000070495944901, 1.0000678285644389, 1.0000652563321863, 1.0000627761509207, 1.0000603849150695, 1.0000580805143373, 1.000055859776211, 1.0000537202207556, 1.0000516593242852, 1.0000496745193639, 1.0000477631948048, 1.0000459226956717, 1.0000441503393105, 1.0000424445256857, 1.0000408024621597, 1.000039222060177, 1.000037701246406, 1.000036237962736, 1.0000348301662811, 1.000033475829377, 1.000032172939582, 1.0000309194996782, 1.0000297137758816, 1.0000285543088978, 1.0000274391648023, 1.0000263667796738, 1.0000253356214222, 1.0000243441897885, 1.0000233910163452, 1.0000224746644957, 1.0000215937294745, 1.000020746838348, 1.000019932650013, 1.0000191498551978, 1.0000183976066614, 1.000017674527786, 1.0000169795221794, 1.0000163115535299, 1.0000156696132905, 1.0000150527206781, 1.000014459922675, 1.000013890294027, 1.0000133429372453, 1.0000128169826044, 1.0000123115881445, 1.00001182593967, 1.0000113592507491, 1.0000109108258814, 1.0000104800633605, 1.0000100661552194, 1.0000096684711834, 1.0000092863989134, 1.0000089193440056, 1.0000085667299905, 1.0000082279983349, 1.0000079026084394, 1.0000075900376413, 1.0000072897812118, 1.0000070013523572, 1.0000067242822201, 1.0000064581198773, 1.0000062024323406, 1.0000059568045578, 1.0000057208416973, 1.0000054942241603, 1.0000052765544856, 1.000005067476474, 1.0000048666521293, 1.0000046737616586]
del2_target_values=[1.0567, 1.045188644166267, 1.0330710054706214, 1.0210113213972747, 1.0090332602616154, 0.9971584766590975, 0.9854066503172662, 0.9737955751195456, 0.9623412024375818, 0.9510577451624997, 0.9399577659577769, 0.9290522363902008, 0.9183506455189581, 0.9078611045499141, 0.8975904395949054, 0.8875442041910119, 0.8777268657090043, 0.8681418599917079, 0.858791663095336, 0.8496778558459428, 0.840801183463983, 0.832161717736997, 0.8237588570196098, 0.815591383109577, 0.8076575728474491, 0.7999551376359946, 0.7924814305912657, 0.7852334470024374, 0.7782078214475316, 0.7714009038465837, 0.7648088256335095, 0.7584274227993835, 0.7522524111964097, 0.7462793865379225, 0.7405038243983861, 0.7349210740841562, 0.7295264429732695, 0.7243152029969568, 0.7192825349978819, 0.7144236459249871, 0.7097337688334933, 0.7052081628849, 0.7008421133469852, 0.6966309309337182, 0.6925699658688557, 0.6886546826121561, 0.6848805544187692, 0.6812431445201764, 0.677738106124192, 0.6743611824149621, 0.6711082065529649, 0.6679751016750112, 0.6649578808942436, 0.6620526453034479, 0.6592555798457682, 0.6565629864886825, 0.6539712669660425, 0.6514769190840918, 0.6490765367214666, 0.646766809829196, 0.6445445244307014, 0.6424065626217972, 0.6403499025706897, 0.6383716185179783, 0.636468880776655, 0.6346389434371852, 0.632879085319277, 0.6311867598515346, 0.6295594976170278, 0.6279949029167139, 0.6264906537694361, 0.6250445019119255, 0.6236542727987989, 0.6223178656025606, 0.6210332532136014, 0.6197984822401987, 0.6186116730085172, 0.6174710195626075, 0.6163748012240318, 0.6153212765223872, 0.6143087746209519, 0.6133357620533846, 0.6124007510315712, 0.6115022994456257, 0.6106390108638885, 0.6098095345329279, 0.6090125653775392, 0.6082468440007451, 0.6075111566837957, 0.6068043353861684, 0.6061252577455677, 0.6054728470779256, 0.6048460723774013, 0.6042439483163814, 0.6036655327940371, 0.603109854002736, 0.6025760533706005, 0.6020632782874432, 0.6015707078420839, 0.6010975528223498]
omega2_target_values=[1.0, 0.9996812436713708, 0.9996824368233903, 0.9996842784487356, 0.9996867149486116, 0.9996896938572059, 0.9996931648623041, 0.999697077882039, 0.9997013873880721, 0.9997060479332407, 0.9997110163949599, 0.9997162537974418, 0.9997217223283824, 0.9997273855022293, 0.9997332109895083, 0.9997391684484528, 0.9997452292572131, 0.9997513667885094, 0.9997575568380925, 0.999763778017076, 0.9997700097391491, 0.9997762336388972, 0.9997824335718024, 0.9997885938436536, 0.9997947022054877, 0.9998007459977208, 0.9998067144397513, 0.9998125986442775, 0.9998183914624751, 0.9998240843396944, 0.9998296726880795, 0.999835150565756, 0.9998405133609886, 0.9998457577921829, 0.9998508819078844, 0.9998558845413487, 0.9998607621230342, 0.9998655153031657, 0.9998701428142027, 0.9998746441546407, 0.99987901958901, 0.9998832701478777, 0.9998873976278456, 0.9998914045184975, 0.9998952889940841, 0.9998990551420898, 0.9999027042000487, 0.9999062377463274, 0.999909657700124, 0.9999129663214692, 0.9999161662112256, 0.9999192603110875, 0.9999222519035816, 0.9999251431627894, 0.9999279349670758, 0.999930631347703, 0.999933234506908, 0.9999357467434296, 0.9999381704525091, 0.9999405081258901, 0.9999427623518182, 0.9999449358150416, 0.9999470312968104, 0.9999490516748772, 0.9999509999234969, 0.999952875892428, 0.9999546833777068, 0.9999564246254994, 0.9999581016505338, 0.9999597164634283, 0.9999612710706909, 0.9999627674747203, 0.999964207673805, 0.9999655936621235, 0.9999669274297447, 0.9999682109626274, 0.9999694462426206, 0.9999706352474634, 0.9999717794121763, 0.9999728792452283, 0.9999739373454042, 0.999974955125786, 0.9999759339733575, 0.9999768752490046, 0.9999777802875146, 0.9999786503975773, 0.9999794868617832, 0.9999802909366254, 0.9999810638524985, 0.999981806813699, 0.999982520998425, 0.9999832075587766, 0.9999838676207554, 0.999984502284265, 0.9999851125893116, 0.9999856986486229, 0.9999862618212212, 0.999986803036109, 0.9999873231407037, 0.999987822900838]
del3_target_values=[0.9449, 0.9233097919293766, 0.9015941600961741, 0.8809449300929801, 0.8613211152265107, 0.8426809446472738, 0.8249823447176721, 0.808183311417506, 0.7922422287961758, 0.7771182078526278, 0.762771217952042, 0.7491623195217852, 0.7362538298554815, 0.7240093894575943, 0.712393991591014, 0.701374131325954, 0.6909177891355154, 0.6809944319614829, 0.6715749401629179, 0.6626317090608779, 0.6541385840829863, 0.6460707700002781, 0.6384048309271991, 0.6311185759401254, 0.6241910812019784, 0.6176026930846807, 0.6113348243075019, 0.6053699537608782, 0.5996916279365222, 0.5942842847938757, 0.5891333103689427, 0.5842250562857106, 0.5795466088275281, 0.5750857889371048, 0.5708311522165118, 0.5667719919656037, 0.5628981119591714, 0.5591999745600454, 0.5556686992992352, 0.5522958575553165, 0.5490734725544307, 0.5459940193702864, 0.5430504249241577, 0.5402360690055024, 0.5375446381763854, 0.5349701103754473, 0.5325069714583156, 0.5301499593453394, 0.5278940640215889, 0.525734527536856, 0.5236668440056537, 0.5216867596072162, 0.5197902725854994, 0.5179736312879412, 0.5162331134153934, 0.5145652965011241, 0.5129669864191772, 0.5114351200222264, 0.5099667651415755, 0.5085591205871591, 0.507209516147542, 0.5059154125899189, 0.5046744016601152, 0.5034842060825865, 0.5023426795604183, 0.5012477514505317, 0.5001973381425661, 0.49918960086856135, 0.4982227711116383, 0.49729514565494826, 0.4964050865816724, 0.4955510212750226, 0.4947314424182408, 0.49394490799459945, 0.49319004128740107, 0.49246553087997874, 0.4917701306556956, 0.4911026597979452, 0.4904620090199738, 0.4898470260884229, 0.48925662878301646, 0.4886898455429012, 0.4881457363942098, 0.48762339295006146, 0.48712193841056123, 0.4866405275628006, 0.4861783467808568, 0.48573461402579343, 0.48530857884566025, 0.48489952237549305, 0.48450675733731385, 0.4841296280401307, 0.4837675103799379, 0.4834198118397158, 0.48308596961157485, 0.48276539120772366, 0.4824575647208955, 0.4821619805328363, 0.4818781490796237, 0.4816056008516666]
omega3_target_values=[1.0, 0.9994153819800515, 0.9994439144548619, 0.99947138498868, 0.9994977667608494, 0.9995230458073683, 0.9995472199737331, 0.9995702936985236, 0.9995922837403288, 0.9996132104741642, 0.9996330991840697, 0.9996519819547705, 0.9996698904002386, 0.9996868629915544, 0.9997029369955647, 0.9997181493895573, 0.9997325380373921, 0.9997461467116603, 0.9997590103287375, 0.9997711690333667, 0.9997826564183131, 0.9997935092146351, 0.9998037672916854, 0.9998134585130574, 0.9998226183399741, 0.9998312742264673, 0.9998394545993428, 0.9998471889394853, 0.9998545072934587, 0.9998614286130719, 0.9998679797275244, 0.9998741804879541, 0.9998800508358443, 0.9998856108030243, 0.9998908805116689, 0.9998958791094255, 0.9999006182293404, 0.9999051158304734, 0.9999093847079507, 0.999913437476675, 0.9999172865713263, 0.9999209442463608, 0.9999244225760119, 0.9999277333577756, 0.9999308816823401, 0.999933879581994, 0.9999367345414052, 0.9999394538722869, 0.9999420447133966, 0.9999445140305362, 0.9999468686165522, 0.9999491150913359, 0.9999512599018225, 0.9999533079394319, 0.9999552627225269, 0.9999571303434196, 0.9999589148077467, 0.9999606200150091, 0.9999622497585731, 0.9999638077256696, 0.999965297497395, 0.9999667225487104, 0.9999680862484422, 0.9999693918592816, 0.9999706425377849, 0.9999718389663892, 0.9999729848895083, 0.9999740825815765, 0.9999751340816475, 0.9999761413730511, 0.9999771063833934, 0.9999780309845566, 0.9999789169926993, 0.999979766168256, 0.9999805802159379, 0.9999813607847319, 0.9999821094679012, 0.9999828278029856, 0.9999835169135983, 0.9999841773704008, 0.9999848110776461, 0.9999854190822689, 0.9999860024030935, 0.9999865620308351, 0.9999870989280973, 0.9999876140293752, 0.9999881082410522, 0.9999885824414029, 0.9999890374805911, 0.9999894741806706, 0.9999898933355852, 0.9999902957111686, 0.9999906820451442, 0.9999910530471254, 0.999991409378609, 0.9999917511542425, 0.999992079230348, 0.9999923941969832, 0.9999926965909772, 0.9999929868959316]

# %%
#10-10.083
del1_target_values.extend([0.2804973072795233, 0.2805051830226228, 0.2805132876769802, 0.28052152499013744, 0.2805298607697809, 0.2805382834328676, 0.28054678945609185, 0.2805553778911808, 0.280564048587638, 0.28057280154696873, 0.280581636782178, 0.2805905542741075, 0.2805995539667384, 0.28060863579163126, 0.2806177996707924, 0.2806270455167802, 0.28063637323921103, 0.28064578274747354, 0.2806552739499121, 0.2806648467545078])
omega1_target_values.extend([1.0000046737616586, 1.0000048667724495, 1.0000049669779199, 1.0000050336071997, 1.0000050886035976, 1.000005139870755, 1.00000519006299, 1.0000052400275043, 1.000005289972429, 1.0000053399321678, 1.000005389889065, 1.0000054398212996, 1.0000054897166084, 1.0000055395661418, 1.0000055893642863, 1.0000056391086325, 1.0000056887981608, 1.0000057384322039, 1.0000057880104263, 1.0000058375326975])
del2_target_values.extend([0.6010975528223498, 0.60143836886673, 0.6022122070548296, 0.603176079912551, 0.6042234434484818, 0.6053073452339547, 0.6064073752449287, 0.6075144226286759, 0.6086245943868577, 0.6097361189284795, 0.6108482298815475, 0.6119606002607958, 0.6130730958608201, 0.6141856439786457, 0.6152982062026754, 0.6164107779536281, 0.6175233573663085, 0.6186359383916308, 0.6197485201064558, 0.620861102090323])
omega2_target_values.extend([0.999987822900838, 1.0003737059970692, 1.0005430780214404, 1.000617432711001, 1.0006500420614564, 1.0006643822871408, 1.000670658400075, 1.000673425826622, 1.0006746310659524, 1.0006751599135633, 1.00067539555545, 1.000675501484247, 1.0006755448026559, 1.0006755618621639, 1.0006755718685703, 1.0006755771115148, 1.0006755785235957, 1.0006755791293553, 1.0006755793903641, 1.0006755795168523])
del3_target_values.extend([0.4816056008516666, 0.48181083408192327, 0.482276085143536, 0.4828552050967025, 0.48348405114994225, 0.4841343303734485, 0.48479373265491055, 0.4854567582352516, 0.48612105525170407, 0.48678555296545567, 0.4874497881465937, 0.4881135633897069, 0.4887767980888316, 0.4894394489054983, 0.49010149330009745, 0.4907629292536171, 0.4914237564092188, 0.4920839718816084, 0.49274357589174145, 0.49340256896722073])
omega3_target_values.extend([0.9999929868959316, 1.000224781456549, 1.000326404594554, 1.0003708474656123, 1.000390145122699, 1.000398428222867, 1.0004018451696832, 1.0004031430899303, 1.0004034969649758, 1.0004034419474714, 1.0004032097827746, 1.0004028994558163, 1.0004025516182231, 1.000402188308696, 1.0004018211778964, 1.0004014516274193, 1.0004010802282481, 1.0004007088136657, 1.000400337665102, 1.000399966910345])

#10.083-12
del1_target_values.extend([0.281479853185354, 0.2797244699792626, 0.27796908677317117, 0.2763432213342058, 0.27484196322150384, 0.27346061179303877, 0.2721946684257292, 0.2710398322829394, 0.2699919893228107, 0.26904720165470586, 0.26820170031425683, 0.2674518803115704, 0.2667942947285722, 0.26622563594073967, 0.26574273610708116, 0.2653425579240618, 0.26502218527453, 0.26477883767151855, 0.2646098368777688, 0.26451260690573])
omega1_target_values.extend([0.9999498111707833, 0.9999532022814843, 0.9999565933921851, 0.9999598564288108, 0.9999629960241033, 0.9999660175084054, 0.999968926025057, 0.9999717264713086, 0.999974423511769, 0.9999770216573937, 0.9999795251548718, 0.9999819380468032, 0.999984264188542, 0.9999865072290414, 0.9999886706156257, 0.9999907576820827, 0.999992771500071, 0.9999947150925012, 0.9999965912970109, 0.9999984027659657])
del2_target_values.extend([0.6188784701647293, 0.625610430816929, 0.6323423914691286, 0.6392035506370786, 0.6461762426936452, 0.6532440967825175, 0.6603919682985124, 0.6676058912164877, 0.6748729869620191, 0.6821813843322749, 0.6895201580672448, 0.6968792845608729, 0.7042495910767445, 0.7116226301279733, 0.7189906821031385, 0.7263466798885022, 0.7336841526019341, 0.7409972946221173, 0.7482807643368053, 0.7555296841428225])
omega2_target_values.extend([1.0001675665158576, 1.0001711161026092, 1.0001746656893606, 1.0001777520517403, 1.000180401319829, 1.0001826462129735, 1.0001845175650603, 1.000186044280565, 1.0001872532329223, 1.0001881700941173, 1.000188818244151, 1.0001892197904425, 1.0001893949755956, 1.000189362890142, 1.0001891414463104, 1.000188746770565, 1.0001881942812583, 1.0001874978574923, 1.0001866705158409, 1.0001857244103487])
del3_target_values.extend([0.48572882172119997, 0.5037969442841478, 0.5218650668470951, 0.5391206343415625, 0.5556125245138324, 0.57138624544017, 0.5864842002763404, 0.6009458195549731, 0.6148078207429644, 0.6281044513764559, 0.6408676383987397, 0.6531271056958878, 0.6649105028321013, 0.6762437440627636, 0.6871510016516861, 0.6976548772054002, 0.7077765477803529, 0.717535591135377, 0.7269504802036096, 0.7360385830924915])
omega3_target_values.extend([1.000496532128309, 1.000475002862589, 1.0004534735968689, 1.0004332437208858, 1.0004142251649975, 1.0003963344365077, 1.0003794941052966, 1.0003636313615603, 1.0003486788034632, 1.0003345752016146, 1.0003212624806916, 1.000308687068408, 1.0002967990175233, 1.0002855527823784, 1.0002749071469508, 1.000264821842539, 1.000255260755101, 1.0002461899449409, 1.000237578088163, 1.0002293964766709])

#12-14
del1_target_values.extend([0.26451260690573, 0.26448480115906275, 0.2645264935132845, 0.26463525191556764, 0.26480876454729135, 0.26504480903438943, 0.26534123961818074, 0.26569598715536974, 0.26610705911804566, 0.26657253959368343, 0.26709058776189404, 0.26765940373864, 0.2682772871543418, 0.2689425930969034, 0.2696537283200113, 0.2704091512431344, 0.2712073719515246, 0.27204695219621605, 0.27292650539402546, 0.2738446974655107])
omega1_target_values.extend([0.9999984027659657, 1.000000185245737, 1.000001905603335, 1.0000035663088478, 1.0000051696421264, 1.0000067178601624, 1.000008213076936, 1.000009657263416, 1.0000110522475605, 1.0000123997143158, 1.0000137016106625, 1.0000149594777488, 1.0000161748964034, 1.0000173494189017, 1.0000184845064388, 1.0000195815291286, 1.000020641766005, 1.0000216664050203, 1.0000226565430475, 1.0000236135703153])
del2_target_values.extend([0.7555296841428225, 0.762878871190614, 0.7701833898405192, 0.777439349826979, 0.7846433956119905, 0.7917925203487305, 0.7988839993975398, 0.8059153903259244, 0.8128845329085551, 0.8197895491272669, 0.826628810281833, 0.8334007914226723, 0.8401043371972607, 0.8467384471633855, 0.8533022604035483, 0.8597950555249634, 0.8662162506595588, 0.8725654034639762, 0.8788422111195705, 0.8850464899793211])
omega2_target_values.extend([1.0001857244103487, 1.00018464943663, 1.0001834736667456, 1.000182207308908, 1.0001808596637347, 1.0001794392488415, 1.0001779540145836, 1.000176411344058, 1.0001748180531012, 1.0001731803902905, 1.0001715040139398, 1.0001697944893322, 1.0001680565501139, 1.0001662945938727, 1.0001645127324246, 1.0001627147918115, 1.0001609043123045, 1.000159084548401, 1.0001572584688254, 1.0001554286371712])
del3_target_values.extend([0.7360385830924915, 0.744983204361647, 0.7536212056215209, 0.7619679098779327, 0.7700373743946041, 0.7778428100832094, 0.7853967318421037, 0.7927109585563241, 0.7997966130975894, 0.8066641223243, 0.8133232919076416, 0.8197836123374505, 0.8260536962723704, 0.8321417400508612, 0.8380555560757587, 0.8438025728142734, 0.8493898347979912, 0.8548240026228736, 0.8601113529492569, 0.865257831598911])
omega3_target_values.extend([1.0002293964766709, 1.0002214722137766, 1.0002139419707905, 1.0002067799052474, 1.0001999639300232, 1.0001934732221462, 1.0001872883211693, 1.0001813911291693, 1.0001757649107468, 1.0001703942930273, 1.0001652648038426, 1.0001603617391355, 1.0001556730330172, 1.000151187285804, 1.0001468936332154, 1.0001427817463742, 1.0001388418318067, 1.0001350646314426, 1.0001314414226155, 1.0001279654507906])

#14-16
del1_target_values.extend([0.2738446974655107, 0.2748002101185121, 0.27579180273889425, 0.2768182745963949, 0.27787845927905835, 0.27897122469323554, 0.280095473063584, 0.28125014093306816, 0.2824341991629589, 0.28364665293283386, 0.2848865453321751, 0.28615293048182744, 0.2874448980637876, 0.28876158411372166, 0.29010214717291355, 0.29146576828826437, 0.29285165101229277, 0.29425902140313487, 0.29568712802454433, 0.29713524194589225])
omega1_target_values.extend([1.0000236135703153, 1.0000245385223463, 1.0000254324282352, 1.0000262963510285, 1.000027131298924, 1.0000279382252706, 1.0000287180285687, 1.0000294715524707, 1.0000301995857792, 1.0000309028624497, 1.0000315821832104, 1.0000322385101152, 1.0000328723832619, 1.0000334845296632, 1.0000340756442705, 1.0000346463899736, 1.0000351973976016, 1.0000357292659223, 1.0000362425616425, 1.0000367378194075])
del2_target_values.extend([0.8850464899793211, 0.8911780560860343, 0.8972369556628468, 0.9032233099969276, 0.909137297987401, 0.9149791561453454, 0.9207491785937937, 0.9264477170677332, 0.9320751809141062, 0.937632037091809, 0.9431188132749377, 0.9485360082120906, 0.9538842009662395, 0.9591640449288555, 0.9643762093055979, 0.9695213791163131, 0.9746002551950347, 0.979613554189985, 0.9845620085635729, 0.9894463665923953])
omega2_target_values.extend([1.0001554286371712, 1.0001535978279699, 1.0001517682089198, 1.0001499417405895, 1.0001481202647948, 1.0001463055045998, 1.0001444990643176, 1.0001427024295084, 1.000140916966981, 1.0001391439247924, 1.0001373842929266, 1.0001356389901994, 1.0001339091176842, 1.0001321953190843, 1.000130498201536, 1.0001288183356094, 1.0001271562553071, 1.0001255124580655, 1.0001238874047544, 1.0001222815196764])
del3_target_values.extend([0.865257831598911, 0.8702692955550173, 0.875151026033448, 0.8799080636105098, 0.8845452436546397, 0.8890671963264022, 0.8934783465784909, 0.8977829141557279, 0.9019849135950642, 0.9060881542255792, 0.9100962365427868, 0.914012762990602, 0.9178410676708362, 0.9215842471993425, 0.9252452897989183, 0.928827075299304, 0.9323323751371833, 0.9357638523561839, 0.9391240616068766, 0.942415449146776])
omega3_target_values.extend([1.0001279654507906, 1.0001246279272886, 1.0001214221707377, 1.0001183422135418, 1.0001153822367679, 1.0001125365701455, 1.000109799692067, 1.0001071662295866, 1.0001046309584223, 1.0001021888029535, 1.000099835917409, 1.0000975693959313, 1.000095383676483, 1.000093275786147, 1.000091242754896, 1.000089281615593, 1.0000873894039903, 1.0000855631587307, 1.0000837999213459, 1.0000820967362583])

#16-18
del1_target_values.extend([0.29713524194589225, 0.29860265674216724, 0.30008868849397524, 0.30159267931180583, 0.30311397417818015, 0.30465193885308334, 0.30620597676412925, 0.3077755058500327, 0.30935995856060977, 0.31095878185677767, 0.31257143721055486, 0.3141974006050608, 0.3158361625345164, 0.31748722800424356, 0.3191501165306654, 0.32082436214130616, 0.32250951337479145, 0.32420513770733467, 0.32591079033713566, 0.32762605475717466])
omega1_target_values.extend([1.0000367378194075, 1.000037215541802, 1.0000376761993492, 1.0000381203249864, 1.0000385486030203, 1.0000389613381837, 1.0000393590059151, 1.0000397420634901, 1.000040110950022, 1.000040466086461, 1.000040807875594, 1.0000411367020459, 1.0000414529322783, 1.0000417569145905, 1.0000420489791184, 1.0000423294378353, 1.0000425985845525, 1.0000428568367634, 1.000043104559022, 1.0000433419617256])
del2_target_values.extend([0.9894463665923953, 0.9942673923672367, 0.9990258657930688, 1.0037225829017107, 1.008358303726426, 1.0129338254885218, 1.0174499756377449, 1.0219075789396803, 1.0263074574757534, 1.0306504306432283, 1.034937315155208, 1.0391689250406346, 1.0433460716442904, 1.0474695636267959, 1.051540206964611, 1.0555588049500348, 1.059526158191206, 1.0634430575044547, 1.067310269473342, 1.0711285846686533])
omega2_target_values.extend([1.0001222815196764, 1.0001206951905675, 1.0001191287685969, 1.0001175823888846, 1.000116056015252, 1.0001145501383801, 1.0001130647565193, 1.000111599864657, 1.0001101554545173, 1.0001087315145611, 1.000107328029986, 1.0001059449827259, 1.0001045823514523, 1.0001032401115728, 1.0001019182352322, 1.0001006166913111, 1.000099335445428, 1.0000980740875844, 1.0000968324616148, 1.0000956106381065])
del3_target_values.extend([0.942415449146776, 0.9456403528403403, 0.9488010021589709, 0.9518995184822963, 0.9549380648570991, 0.957918633070706, 0.9608430673633025, 0.9637131548189733, 0.9665306253657027, 0.969297151775374, 0.9720143496637698, 0.9746837774905719, 0.9773069365593617, 0.9798852710176196, 0.9824201678567254, 0.9849129569119579, 0.9873649108624958, 0.989777262970899, 0.9921512985863296, 0.994488145141392])
omega3_target_values.extend([1.0000820967362583, 1.00008045065078, 1.0000788587151135, 1.0000773192080008, 1.0000758318912235, 1.0000743924061057, 1.0000729993449864, 1.0000716512652668, 1.0000703466894125, 1.000069084104951, 1.0000678619644734, 1.0000666786856331, 1.0000655326511474, 1.000064422208796, 1.0000633456714214, 1.0000623013169296, 1.00006128738829, 1.0000603045070704, 1.0000593518143466, 1.0000584267213835])


#18-20
del1_target_values.extend([0.32762605475717466, 0.32935053534527053, 0.3310838456219279, 0.332825608250337, 0.33457545503637415, 0.336333026928601, 0.33809797401826525, 0.3398699555393003, 0.3416486398683253, 0.3434337045246451, 0.3452248361702505, 0.3470217306098178, 0.3488240927907091, 0.35063163680297244, 0.352444075965482, 0.3542611431738589, 0.3560825770023863, 0.3579081208194269, 0.359737524858548, 0.36157054621852186])
omega1_target_values.extend([1.0000433419617256, 1.0000435693445726, 1.0000437869973784, 1.0000439952000748, 1.0000441942227107, 1.0000443843254523, 1.000044565758582, 1.0000447387624998, 1.0000449035677221, 1.000045060394883, 1.0000452094547319, 1.000045350948137, 1.0000454850660818, 1.0000456119896683, 1.0000457320314782, 1.0000458453625238, 1.000045952134661, 1.000046052524471, 1.0000461467077724, 1.000046234859619])
del2_target_values.extend([1.0711285846686533, 1.0748987883217245, 1.0786216567129518, 1.0822979571717937, 1.0859284480767692, 1.0895138788554593, 1.0930549899845057, 1.0965525129896125, 1.1000071704455439, 1.1034196759761266, 1.1067907342542473, 1.1101210410018552, 1.1134112829899603, 1.1166621380386343, 1.1198742521762992, 1.1230483015848098, 1.1261849436900713, 1.1292848204353307, 1.1323485641945035, 1.135376797772173])
omega2_target_values.extend([1.0000956106381065, 1.0000944083766634, 1.0000932254434869, 1.0000920616113744, 1.0000909166597207, 1.0000897903745167, 1.0000886825483506, 1.0000875929804072, 1.0000865214764676, 1.0000854678489102, 1.0000844319167097, 1.0000834135054382, 1.0000824124472638, 1.0000814285809514, 1.000080461352789, 1.0000795105387197, 1.000078576006844, 1.0000776575388481, 1.0000767548949228, 1.0000758678137616])
del3_target_values.extend([0.994488145141392, 0.9967888733259774, 0.9990545238037348, 1.00128610721207, 1.0034846041621468, 1.0056509652388868, 1.0077861110009683, 1.0098909319808276, 1.011966288684659, 1.0140130115924135, 1.0160319011578003, 1.0180237278082855, 1.0199892319450934, 1.021929123943205, 1.0238441807700551, 1.0257350315390132, 1.0276023004934935, 1.0294466128634976, 1.03126857387176, 1.0330687687337485])
omega3_target_values.extend([1.0000584267213835, 1.0000575285787356, 1.000056656703183, 1.0000558103777288, 1.0000549888516015, 1.0000541913402539, 1.0000534170253628, 1.0000526650548307, 1.0000519345427832, 1.000051224569571, 1.0000505341817698, 1.0000498623921787, 1.000049208179822, 1.0000485704899487, 1.000047951046516, 1.0000473487301063, 1.0000467624575886, 1.0000461916985952, 1.0000456359324825, 1.0000450946483306])

# %%
t_data = np.linspace(0, 10, 20*(int(10/2))).tolist()
t_data.extend((np.linspace(10, 10.083, 20)).tolist())
t_data.extend((np.linspace(10.083, 12, 20)).tolist())
t_data.extend((np.linspace(12, 20, 80)).tolist())

print(len(t_data))
print(len(del3_target_values))
print(len(del1))
# Out:
# 220
# 220
# 220

# %%
Ws = 376.9911

# %%
# delta1_omega1

plt.figure()
plt.scatter(t_data, del1_target_values, label='Precise $\delta_1$', alpha=1)
plt.plot(t_data, del1, 'r',label='Approximation $\delta_1$')
plt.xlabel('$t$')
plt.ylabel('$\delta_1$')
plt.legend()
# plt.title('Fitting Data')
plt.grid(True)
print(del1_target_values[-1])


plt.figure()
plt.scatter(t_data, omega1_target_values, label='Precise $\omega_1$', alpha=1)
plt.plot(t_data, omega1,'r', label='Approximation $\omega_1$')
plt.xlabel('$t$')
plt.ylabel('$\omega$_1')
plt.legend()
# plt.title('Fitting Data')
plt.grid(True)
plt.ylim([min(omega1_target_values)-0.00001, max(omega1_target_values)+0.00001])

# delta2_omega2
plt.figure()
plt.scatter(t_data, del2_target_values ,label='Precise $\delta_2$', alpha=1)
plt.plot(t_data,del2, 'r',label='Approximation $\delta_2$')
plt.xlabel('$t$')
plt.ylabel('$\delta_2$')
plt.legend()
# plt.title('Fitting Data')
plt.grid(True)

# plt.subplot(2, 1, 2)
plt.figure()
plt.scatter(t_data, omega2_target_values, label='Precise $\omega_2$', alpha=1)
plt.plot(t_data, omega2,'r', linewidth=1, label='Approximation $\omega_2$')
plt.xlabel('$t$')
plt.ylabel('$\omega_2$')
plt.legend()
# plt.title('Fitting Data')
plt.grid(True)
plt.ylim([min(omega2_target_values)-0.0001, max(omega2_target_values)+0.0001])

# delta3_omega3
plt.figure()
plt.scatter(t_data, del3_target_values, label='Precise $\delta_2$', alpha=1)
plt.plot(t_data, del3,'r', label='Approximation $\delta_3$')
plt.xlabel('$t$')
plt.ylabel('$\delta_3$')
plt.legend()
# plt.title('Fitting Data')
plt.grid(True)


plt.figure()
plt.scatter(t_data, omega3_target_values, label='Precise $\omega_3$', alpha=1)
plt.plot(t_data, omega3,'r', label='Approximation $\omega_3$')
plt.xlabel('$t$')
plt.ylabel('$\omega_3$')
plt.legend()
# plt.title('Fitting Data')
plt.grid(True)
plt.ylim([min(omega3_target_values)-0.0002, max(omega3_target_values)+0.0002])
# Out:
# 0.36157054621852186
# (0.9992153819800516, 1.000696532128309)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have already defined your data and functions

# Create a 3x2 grid of subplots
fig, axs = plt.subplots(3, 2, figsize=(12, 12))

# Adjust layout for better spacing
plt.tight_layout()

# Plot for delta1_omega1
axs[0, 0].scatter(t_data, del1_target_values, label='Precise $\delta_1$', alpha=1)
axs[0, 0].plot(t_data, del1, 'r',label='Approximation $\delta_1$')
axs[0, 0].set_xlabel('$t$')
axs[0, 0].set_ylabel('$\delta_1$')
axs[0, 0].legend()
axs[0, 0].grid(True)

axs[0, 1].scatter(t_data, omega1_target_values, label='Precise $\omega_1$', alpha=1)
axs[0, 1].plot(t_data, omega1,'r', label='Approximation $\omega_1$')
axs[0, 1].set_xlabel('$t$')
axs[0, 1].set_ylabel('$\omega_1$')
axs[0, 1].legend()
axs[0, 1].grid(True)
axs[0, 1].set_ylim([min(omega1_target_values)-0.00001, max(omega1_target_values)+0.00001])

# Plot for delta2_omega2
axs[1, 0].scatter(t_data, del2_target_values, label='Precise $\delta_2$', alpha=1)
axs[1, 0].plot(t_data, del2, 'r',label='Approximation $\delta_2$')
axs[1, 0].set_xlabel('$t$')
axs[1, 0].set_ylabel('$\delta_2$')
axs[1, 0].legend()
axs[1, 0].grid(True)

axs[1, 1].scatter(t_data, omega2_target_values, label='Precise $\omega_2$', alpha=1)
axs[1, 1].plot(t_data, omega2,'r', linewidth=1, label='Approximation $\omega_2$')
axs[1, 1].set_xlabel('$t$')
axs[1, 1].set_ylabel('$\omega_2$')
axs[1, 1].legend()
axs[1, 1].grid(True)
axs[1, 1].set_ylim([min(omega2_target_values)-0.0001, max(omega2_target_values)+0.0001])

# Plot for delta3_omega3
axs[2, 0].scatter(t_data, del3_target_values, label='Precise $\delta_3$', alpha=1)
axs[2, 0].plot(t_data, del3,'r', label='Approximation $\delta_3$')
axs[2, 0].set_xlabel('$t$')
axs[2, 0].set_ylabel('$\delta_3$')
axs[2, 0].legend()
axs[2, 0].grid(True)

axs[2, 1].scatter(t_data, omega3_target_values, label='Precise $\omega_3$', alpha=1)
axs[2, 1].plot(t_data, omega3,'r', label='Approximation $\omega_3$')
axs[2, 1].set_xlabel('$t$')
axs[2, 1].set_ylabel('$\omega_3$')
axs[2, 1].legend()
axs[2, 1].grid(True)
axs[2, 1].set_ylim([min(omega3_target_values)-0.0002, max(omega3_target_values)+0.0002])

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have already defined your data and functions

# Create a 3x2 grid of subplots with padding and border
fig, axs = plt.subplots(3, 2, figsize=(20, 14), gridspec_kw={'hspace': 0.04, 'wspace': 0.06})

# Adjust layout for better spacing
# plt.tight_layout()

# Add padding and border to each subplot
for ax in axs.flatten():
    ax.set_position([ax.get_position().x0, ax.get_position().y0, ax.get_position().width, ax.get_position().height])
    ax.set_position([ax.get_position().x0 + 0.05, ax.get_position().y0 + 0.05, ax.get_position().width - 0.05, ax.get_position().height - 0.05])

# Plot for delta1_omega1
axs[0, 0].scatter(t_data, del1_target_values, label='Precise $\delta_1$', alpha=1)
axs[0, 0].plot(t_data, del1, 'r',label='Approximation $\delta_1$')
axs[0, 0].set_xlabel('$t$', fontsize=15)
axs[0, 0].set_ylabel('$\delta_1$', fontsize=15)
axs[0, 0].legend(fontsize=13)
axs[0, 0].grid(True)

axs[0, 1].scatter(t_data, omega1_target_values, label='Precise $\omega_1$', alpha=1)
axs[0, 1].plot(t_data, omega1,'r', label='Approximation $\omega_1$')
axs[0, 1].set_xlabel('$t$', fontsize=15)
axs[0, 1].set_ylabel('$\omega_1$', fontsize=15)
axs[0, 1].legend(fontsize=13)
axs[0, 1].grid(True)
axs[0, 1].set_ylim([min(omega1_target_values)-0.00001, max(omega1_target_values)+0.00001])

# Plot for delta2_omega2
axs[1, 0].scatter(t_data, del2_target_values, label='Precise $\delta_2$', alpha=1)
axs[1, 0].plot(t_data, del2, 'r',label='Approximation $\delta_2$')
axs[1, 0].set_xlabel('$t$', fontsize=15)
axs[1, 0].set_ylabel('$\delta_2$', fontsize=15)
axs[1, 0].legend(fontsize=13)
axs[1, 0].grid(True)

axs[1, 1].scatter(t_data, omega2_target_values, label='Precise $\omega_2$', alpha=1)
axs[1, 1].plot(t_data, omega2,'r', linewidth=1, label='Approximation $\omega_2$')
axs[1, 1].set_xlabel('$t$', fontsize=15)
axs[1, 1].set_ylabel('$\omega_2$', fontsize=15)
axs[1, 1].legend(fontsize=13)
axs[1, 1].grid(True)
axs[1, 1].set_ylim([min(omega2_target_values)-0.0001, max(omega2_target_values)+0.0001])

# Plot for delta3_omega3
axs[2, 0].scatter(t_data, del3_target_values, label='Precise $\delta_3$', alpha=1)
axs[2, 0].plot(t_data, del3,'r', label='Approximation $\delta_3$')
axs[2, 0].set_xlabel('$t$', fontsize=15)
axs[2, 0].set_ylabel('$\delta_3$', fontsize=15)
axs[2, 0].legend(fontsize=13)
axs[2, 0].grid(True)

axs[2, 1].scatter(t_data, omega3_target_values, label='Precise $\omega_3$', alpha=1)
axs[2, 1].plot(t_data, omega3,'r', label='Approximation $\omega_3$')
axs[2, 1].set_xlabel('$t$', fontsize=15)
axs[2, 1].set_ylabel('$\omega_3$', fontsize=15)
axs[2, 1].legend(fontsize=13)
axs[2, 1].grid(True)
axs[2, 1].set_ylim([min(omega3_target_values)-0.0002, max(omega3_target_values)+0.0002])

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have already defined your data and functions

# Create a 3x2 grid of subplots with padding and border
fig, axs = plt.subplots(3, 2, figsize=(20, 14), gridspec_kw={'hspace': 0.04, 'wspace': 0.06})

# Adjust layout for better spacing
# plt.tight_layout()

# Add padding and border to each subplot
for ax in axs.flatten():
    ax.set_position([ax.get_position().x0, ax.get_position().y0, ax.get_position().width, ax.get_position().height])
    ax.set_position([ax.get_position().x0 + 0.05, ax.get_position().y0 + 0.05, ax.get_position().width - 0.05, ax.get_position().height - 0.05])


#Initial Condition Setup:
del1[0]=del1_target_values[0]    
omega1[0]=omega1_target_values[0]   
del2[0]=del2_target_values[0]    
omega2[0]=omega2_target_values[0]   
del3[0]=del3_target_values[0]    
omega3[0]=omega3_target_values[0]   


# Plot for delta1_omega1
axs[0, 0].plot(t_data, del1_target_values, 'g',label='Actual $\delta_1$', alpha=1)
axs[0, 0].plot(t_data, del1, 'r--',label='Approximation $\delta_1$')
axs[0, 0].set_xlabel('$t$', fontsize=15)
axs[0, 0].set_ylabel('$\delta_1$', fontsize=15)
axs[0, 0].legend(fontsize=13)
axs[0, 0].grid(True)

axs[0, 1].plot(t_data, omega1_target_values, 'g',label='Actual $\omega_1$', alpha=1)
axs[0, 1].plot(t_data, omega1,'r--',label='Approximation $\omega_1$')
axs[0, 1].set_xlabel('$t$', fontsize=15)
axs[0, 1].set_ylabel('$\omega_1$', fontsize=15)
axs[0, 1].legend(fontsize=13)
axs[0, 1].grid(True)
axs[0, 1].set_ylim([min(omega1_target_values)-0.00001, max(omega1_target_values)+0.00001])

# Plot for delta2_omega2
axs[1, 0].plot(t_data, del2_target_values, 'g',label='Actual $\delta_2$', alpha=1)
axs[1, 0].plot(t_data, del2, 'r--',label='Approximation $\delta_2$')
axs[1, 0].set_xlabel('$t$', fontsize=15)
axs[1, 0].set_ylabel('$\delta_2$', fontsize=15)
axs[1, 0].legend(fontsize=13)
axs[1, 0].grid(True)

axs[1, 1].plot(t_data, omega2_target_values, 'g',label='Actual $\omega_2$', alpha=1)
axs[1, 1].plot(t_data, omega2,'r--', linewidth=1,label='Approximation $\omega_2$')
axs[1, 1].set_xlabel('$t$', fontsize=15)
axs[1, 1].set_ylabel('$\omega_2$', fontsize=15)
axs[1, 1].legend(fontsize=13)
axs[1, 1].grid(True)
axs[1, 1].set_ylim([min(omega2_target_values)-0.0001, max(omega2_target_values)+0.0001])

# Plot for delta3_omega3
axs[2, 0].plot(t_data, del3_target_values, 'g',label='Actual $\delta_3$', alpha=1)
axs[2, 0].plot(t_data, del3,'r--',label='Approximation $\delta_3$')
axs[2, 0].set_xlabel('$t$', fontsize=15)
axs[2, 0].set_ylabel('$\delta_3$', fontsize=15)
axs[2, 0].legend(fontsize=13)
axs[2, 0].grid(True)

axs[2, 1].plot(t_data, omega3_target_values, 'g',label='Actual $\omega_3$', alpha=1)
axs[2, 1].plot(t_data, omega3,'r--',label='Approximation $\omega_3$')
axs[2, 1].set_xlabel('$t$', fontsize=15)
axs[2, 1].set_ylabel('$\omega_3$', fontsize=15)
axs[2, 1].legend(fontsize=13)
axs[2, 1].grid(True)
axs[2, 1].set_ylim([min(omega3_target_values)-0.0002, max(omega3_target_values)+0.0002])

# Show the plot
plt.show()

# %%
import pandas as pd

# Assuming all variables are defined and have the same length
data = {
    't_data': t_data,
    'del1_target_values': del1_target_values,
    'del1': del1,
    'omega1_target_values': omega1_target_values,
    'omega1': omega1,
    'del2_target_values': del2_target_values,
    'del2': del2,
    'omega2_target_values': omega2_target_values,
    'omega2': omega2,
    'del3_target_values': del3_target_values,
    'del3': del3,
    'omega3_target_values': omega3_target_values,
    'omega3': omega3
}

df = pd.DataFrame(data)
df.to_csv('../data.csv', index=False)

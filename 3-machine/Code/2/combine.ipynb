# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def convertStrToArr(string_data):
    values = string_data.strip('[]').split()
    # return np.array([float(value) for value in values])
    return [float(value) for value in values]

# %%
#0-2
del1= [0.06276933526831452, 0.07088896123002156, 0.07879282006882005, 0.08648091178471001, 0.09395323637769143, 0.10120979384776432, 0.10825058419492872, 0.11507560741918454, 0.12168486352053184, 0.1280783524989706, 0.13425607435450088, 0.14021802908712255, 0.14596421669683574, 0.15149463718364042, 0.1568092905475365, 0.1619081767885241, 0.16679129590660313, 0.17145864790177368, 0.1759102327740356, 0.1801460505233891]
del2= [1.056851877148677, 1.0440069525521292, 1.0313393981122068, 1.0188492138289102, 1.0065363997022394, 0.994400955732194, 0.9824428819187744, 0.9706621782619804, 0.9590588447618121, 0.9476328814182695, 0.9363842882313526, 0.9253130652010613, 0.9144192123273958, 0.9037027296103557, 0.8931636170499415, 0.8828018746461529, 0.8726175023989899, 0.8626105003084527, 0.8527808683745409, 0.843128606597255]
del3= [0.9367983846835483, 0.9175925598802722, 0.8988553114979344, 0.8805866395365347, 0.8627865439960734, 0.8454550248765502, 0.8285920821779653, 0.8121977159003186, 0.7962719260436101, 0.7808147126078399, 0.7658260755930077, 0.751306014999114, 0.7372545308261584, 0.7236716230741411, 0.710557291743062, 0.697911536832921, 0.6857343583437183, 0.674025756275454, 0.6627857306281277, 0.6520142814017398]
omega1= [1.0002046107895814, 1.0002018921741187, 1.000196454943193, 1.0001910177122673, 1.0001855804813415, 1.0001801432504158, 1.0001747060194903, 1.0001692687885646, 1.0001638315576389, 1.0001583943267132, 1.0001529570957874, 1.0001475198648617, 1.000142082633936, 1.0001366454030103, 1.0001312081720848, 1.000125770941159, 1.0001203337102333, 1.0001148964793076, 1.000109459248382, 1.0001067406329192]
omega2= [0.9996763138873379, 0.9996785487099742, 0.9996830183552469, 0.9996874880005195, 0.9996919576457922, 0.9996964272910648, 0.9997008969363375, 0.9997053665816101, 0.9997098362268827, 0.9997143058721554, 0.999718775517428, 0.9997232451627006, 0.9997277148079733, 0.999732184453246, 0.9997366540985186, 0.9997411237437912, 0.9997455933890639, 0.9997500630343366, 0.9997545326796092, 0.9997567675022455]
omega3= [0.999516022167019, 0.9995219261207183, 0.999533734028117, 0.9995455419355156, 0.9995573498429142, 0.9995691577503129, 0.9995809656577116, 0.9995927735651102, 0.9996045814725089, 0.9996163893799075, 0.9996281972873061, 0.9996400051947048, 0.9996518131021034, 0.999663621009502, 0.9996754289169008, 0.9996872368242994, 0.999699044731698, 0.9997108526390966, 0.9997226605464953, 0.9997285645001946]

#2-4
del1.extend([0.17974896820520125, 0.18381473388145017, 0.1877636640850751, 0.1915957588160761, 0.19531101807445322, 0.19890944186020632, 0.2023910301733355, 0.20575578301384073, 0.20900370038172195, 0.2121347822769793, 0.21514902869961278, 0.21804643964962214, 0.22082701512700756, 0.22349075513176916, 0.2260376596639067, 0.22846772872342047, 0.23078096231031014, 0.23297736042457584, 0.23505692306621762, 0.23701965023523558])
del2.extend([0.8417695255844526, 0.8331219356591868, 0.8246790206893279, 0.8164407806748757, 0.8084072156158308, 0.8005783255121928, 0.7929541103639615, 0.7855345701711374, 0.7783197049337199, 0.7713095146517097, 0.7645039993251064, 0.7579031589539098, 0.7515069935381203, 0.745315503077738, 0.7393286875727623, 0.7335465470231939, 0.7279690814290317, 0.722596290790277, 0.7174281751069291, 0.7124647343789883])
del3.extend([0.6499429896178659, 0.6443487421370795, 0.6387762021308002, 0.6332253695990283, 0.6276962445417643, 0.6221888269590079, 0.6167031168507591, 0.6112391142170186, 0.6057968190577852, 0.6003762313730598, 0.5949773511628416, 0.5896001784271304, 0.5842447131659265, 0.5789109553792312, 0.5735989050670443, 0.5683085622293644, 0.5630399268661921, 0.5577929989775275, 0.55256777856337, 0.547364265623721])
omega1.extend([1.00010245539994, 1.0001009833002144, 1.0000980391007626, 1.0000950949013108, 1.000092150701859, 1.0000892065024074, 1.0000862623029556, 1.0000833181035038, 1.000080373904052, 1.0000774297046005, 1.0000744855051487, 1.0000715413056969, 1.0000685971062453, 1.0000656529067935, 1.0000627087073417, 1.00005976450789, 1.0000568203084383, 1.0000538761089866, 1.0000509319095348, 1.0000494598098089])
omega2.extend([0.999782084764627, 0.9997846636213644, 0.9997898213348393, 0.9997949790483142, 0.9998001367617889, 0.9998052944752638, 0.9998104521887387, 0.9998156099022135, 0.9998207676156883, 0.9998259253291631, 0.999831083042638, 0.9998362407561129, 0.9998413984695877, 0.9998465561830625, 0.9998517138965374, 0.9998568716100122, 0.9998620293234871, 0.9998671870369619, 0.9998723447504367, 0.9998749236071742])
omega3.extend([0.999859027571029, 0.9998593010801486, 0.9998598480983881, 0.9998603951166276, 0.9998609421348671, 0.9998614891531066, 0.9998620361713461, 0.9998625831895855, 0.999863130207825, 0.9998636772260645, 0.999864224244304, 0.9998647712625435, 0.999865318280783, 0.9998658652990224, 0.9998664123172619, 0.9998669593355014, 0.9998675063537409, 0.9998680533719804, 0.9998686003902199, 0.9998688738993396])

#4-6
del1.extend([0.2368075261579652, 0.23870142759614854, 0.24053962208112534, 0.2423221096128953, 0.24404889019145876, 0.24571996381681566, 0.2473353304889659, 0.24889499020790923, 0.25039894297364623, 0.25184718878617657, 0.25323972764550023, 0.2545765595516174, 0.25585768450452784, 0.25708310250423133, 0.2582528135507286, 0.25936681764401887, 0.26042511478410296, 0.26142770497098033, 0.2623745882046507, 0.2632657644851147])
del2.extend([0.7110278522608431, 0.7065476019522359, 0.7021867510840546, 0.6979452996562996, 0.693823247668971, 0.6898205951220683, 0.6859373420155919, 0.6821734883495418, 0.6785290341239174, 0.6750039793387204, 0.6715983239939487, 0.668312068089603, 0.6651452116256833, 0.6620977546021908, 0.6591696970191234, 0.6563610388764824, 0.6536717801742684, 0.6511019209124804, 0.6486514610911177, 0.6463204007101813])
del3.extend([0.5475923700462774, 0.5456385066610195, 0.5436612852489587, 0.5416607058100951, 0.5396367683444285, 0.537589472851959, 0.5355188193326867, 0.5334248077866114, 0.5313074382137332, 0.5291667106140521, 0.5270026249875681, 0.5248151813342812, 0.5226043796541914, 0.5203702199472986, 0.518112702213603, 0.5158318264531044, 0.513527592665803, 0.5112000008516986, 0.5088490510107913, 0.506474743143081])
omega1.extend([1.0000477254334723, 1.0000470235388448, 1.0000456197495897, 1.0000442159603347, 1.0000428121710794, 1.0000414083818243, 1.0000400045925693, 1.000038600803314, 1.000037197014059, 1.0000357932248036, 1.0000343894355486, 1.0000329856462935, 1.0000315818570382, 1.0000301780677832, 1.000028774278528, 1.0000273704892728, 1.0000259667000178, 1.0000245629107627, 1.0000231591215074, 1.0000224572268799])
omega2.extend([0.9998870997805206, 0.9998886041856433, 0.9998916129958885, 0.9998946218061338, 0.999897630616379, 0.9999006394266242, 0.9999036482368695, 0.9999066570471148, 0.9999096658573601, 0.9999126746676053, 0.9999156834778505, 0.9999186922880957, 0.999921701098341, 0.9999247099085863, 0.9999277187188316, 0.9999307275290767, 0.999933736339322, 0.9999367451495673, 0.9999397539598125, 0.9999412583649352])
omega3.extend([0.9999507635534103, 0.9999504692477162, 0.9999498806363283, 0.9999492920249403, 0.9999487034135524, 0.9999481148021644, 0.9999475261907764, 0.9999469375793884, 0.9999463489680004, 0.9999457603566124, 0.9999451717452245, 0.9999445831338365, 0.9999439945224485, 0.9999434059110606, 0.9999428172996725, 0.9999422286882845, 0.9999416400768966, 0.9999410514655086, 0.9999404628541206, 0.9999401685484266])
#6-8
del1.extend([0.26313518269093344, 0.2640118359152952, 0.2648619935913251, 0.26568565571902325, 0.2664828222983898, 0.2672534933294247, 0.2679976688121278, 0.2687153487464991, 0.26940653313253893, 0.27007122197024663, 0.27070941525962305, 0.2713211130006673, 0.2719063151933802, 0.27246502183776117, 0.27299723293381073, 0.27350294848152834, 0.27398216848091417, 0.27443489293196843, 0.2748611218346908, 0.27526085518908183])
del2.extend([0.6451472535822982, 0.6432567062839123, 0.6414011013170813, 0.6395804386818055, 0.6377947183780848, 0.6360439404059187, 0.6343281047653079, 0.6326472114562516, 0.6310012604787509, 0.6293902518328047, 0.6278141855184137, 0.6262730615355777, 0.6247668798842967, 0.6232956405645704, 0.6218593435763993, 0.6204579889197831, 0.6190915765947219, 0.6177601066012158, 0.6164635789392645, 0.6152019936088683])
del3.extend([0.5070832514968301, 0.5064925579677331, 0.5058533558828925, 0.5051656452423092, 0.504429426045981, 0.5036446982939085, 0.5028114619860921, 0.5019297171225319, 0.5009994637032285, 0.5000207017281775, 0.4989934311973853, 0.4979176521108496, 0.49679336446856687, 0.49562056827054135, 0.4943992635167742, 0.4931294502072585, 0.4918111283420019, 0.49044429792099936, 0.4890289589442556, 0.4875651114117667])
omega1.extend([1.0000220912526354, 1.0000217574149015, 1.0000210897394335, 1.0000204220639652, 1.0000197543884972, 1.0000190867130292, 1.0000184190375612, 1.0000177513620931, 1.000017083686625, 1.0000164160111569, 1.0000157483356888, 1.0000150806602208, 1.0000144129847526, 1.0000137453092846, 1.0000130776338165, 1.0000124099583485, 1.0000117422828805, 1.0000110746074122, 1.0000104069319442, 1.0000100730942103])
omega2.extend([0.999952359089287, 0.9999527993545212, 0.9999536798849893, 0.9999545604154575, 0.9999554409459256, 0.9999563214763938, 0.9999572020068619, 0.9999580825373301, 0.9999589630677982, 0.9999598435982664, 0.9999607241287345, 0.9999616046592027, 0.9999624851896708, 0.999963365720139, 0.9999642462506071, 0.9999651267810753, 0.9999660073115434, 0.9999668878420116, 0.9999677683724797, 0.9999682086377139])
omega3.extend([0.999985114798396, 0.9999845036018988, 0.9999832812089045, 0.9999820588159102, 0.9999808364229158, 0.9999796140299214, 0.9999783916369271, 0.9999771692439328, 0.9999759468509384, 0.9999747244579441, 0.9999735020649498, 0.9999722796719555, 0.9999710572789611, 0.9999698348859668, 0.9999686124929724, 0.999967390099978, 0.9999661677069838, 0.9999649453139894, 0.9999637229209951, 0.9999631117244979])
#8-10
del1.extend([0.275217291057552, 0.27549484096989196, 0.27577578078685894, 0.2760601105084529, 0.27634783013467384, 0.2766389396655217, 0.27693343910099655, 0.2772313284410984, 0.27753260768582716, 0.27783727683518294, 0.2781453358891656, 0.2784567848477753, 0.278771623711012, 0.27908985247887563, 0.2794114711513662, 0.2797364797284838, 0.2800648782102283, 0.2803966665965998, 0.2807318448875983, 0.2810704130832237])
del2.extend([0.613175136368259, 0.6127158208355655, 0.6122508288238682, 0.6117801603331672, 0.6113038153634625, 0.610821793914754, 0.6103340959870417, 0.6098407215803258, 0.609341670694606, 0.6088369433298826, 0.6083265394861553, 0.6078104591634245, 0.6072887023616897, 0.6067612690809514, 0.6062281593212092, 0.6056893730824634, 0.6051449103647137, 0.6045947711679605, 0.6040389554922033, 0.6034774633374425])
del3.extend([0.4802474996265266, 0.4810553418079655, 0.48187197991854774, 0.48269741395827315, 0.4835316439271418, 0.48437466982515376, 0.4852264916523089, 0.48608710940860733, 0.48695652309404897, 0.48783473270863387, 0.48872173825236204, 0.4896175397252334, 0.490522137127248, 0.49143553045840593, 0.492357719718707, 0.49328870490815135, 0.49422848602673897, 0.49517706307446985, 0.49613443605134394, 0.49710060495736125])
omega1.extend([1.0000069941284218, 1.00000703684043, 1.0000071222644464, 1.000007207688463, 1.0000072931124795, 1.000007378536496, 1.0000074639605125, 1.000007549384529, 1.0000076348085456, 1.0000077202325621, 1.0000078056565787, 1.0000078910805952, 1.0000079765046117, 1.0000080619286282, 1.0000081473526448, 1.0000082327766613, 1.0000083182006778, 1.0000084036246943, 1.0000084890487109, 1.000008531760719])
omega2.extend([0.9999884254626685, 0.999988353940356, 0.999988210895731, 0.9999880678511059, 0.9999879248064809, 0.9999877817618559, 0.999987638717231, 0.9999874956726059, 0.9999873526279809, 0.9999872095833559, 0.9999870665387308, 0.9999869234941058, 0.9999867804494807, 0.9999866374048557, 0.9999864943602308, 0.9999863513156058, 0.9999862082709807, 0.9999860652263557, 0.9999859221817307, 0.9999858506594181])
omega3.extend([1.0000203572464275, 1.0000204680730846, 1.0000206897263992, 1.0000209113797138, 1.0000211330330284, 1.0000213546863428, 1.0000215763396574, 1.000021797992972, 1.0000220196462863, 1.000022241299601, 1.0000224629529155, 1.00002268460623, 1.0000229062595445, 1.000023127912859, 1.0000233495661734, 1.000023571219488, 1.0000237928728026, 1.0000240145261172, 1.0000242361794316, 1.000024347006089])

#10-12
del1.extend([0.2805524523192475, 0.28067626991395084, 0.2808015767542513, 0.28092837284014893, 0.28105665817164366, 0.28118643274873556, 0.2813176965714246, 0.28145044963971066, 0.2815846919535939, 0.28172042351307436, 0.28185764431815186, 0.28199635436882653, 0.2821365536650983, 0.28227824220696723, 0.2824214199944333, 0.28256608702749647, 0.2827122433061568, 0.28285988883041424, 0.2830090236002688, 0.28315964761572054])
del2.extend([0.6003097939146925, 0.6000552722195727, 0.5998027940337601, 0.5995523593572548, 0.5993039681900566, 0.5990576205321657, 0.5988133163835819, 0.5985710557443055, 0.5983308386143362, 0.598092664993674, 0.5978565348823193, 0.5976224482802716, 0.5973904051875311, 0.5971604056040979, 0.5969324495299719, 0.5967065369651532, 0.5964826679096416, 0.5962608423634373, 0.5960410603265401, 0.5958233217989503])
del3.extend([0.47730825567375496, 0.47766985353532765, 0.47803453582764416, 0.4784023025507045, 0.47877315370450857, 0.4791470892890565, 0.4795241093043483, 0.4799042137503839, 0.4802874026271633, 0.4806736759346865, 0.48106303367295355, 0.48145547584196435, 0.481851002441719, 0.4822496134722175, 0.4826513089334598, 0.48305608882544593, 0.48346395314817586, 0.48387490190164956, 0.4842889350858671, 0.4847060527008285])
omega1.extend([1.0000031201456736, 1.0000031389098212, 1.000003176438116, 1.000003213966411, 1.0000032514947057, 1.0000032890230006, 1.0000033265512955, 1.0000033640795905, 1.0000034016078854, 1.0000034391361803, 1.0000034766644752, 1.0000035141927701, 1.000003551721065, 1.00000358924936, 1.0000036267776546, 1.0000036643059496, 1.0000037018342445, 1.0000037393625394, 1.0000037768908343, 1.0000037956549817])
omega2.extend([0.9999935861719186, 0.9999936119196595, 0.9999936634151416, 0.9999937149106236, 0.9999937664061057, 0.9999938179015877, 0.9999938693970698, 0.9999939208925518, 0.9999939723880338, 0.9999940238835159, 0.9999940753789979, 0.99999412687448, 0.999994178369962, 0.9999942298654441, 0.999994281360926, 0.9999943328564082, 0.9999943843518901, 0.9999944358473721, 0.9999944873428542, 0.9999945130905953])
omega3.extend([1.0000091120975667, 1.0000091509606752, 1.0000092286868922, 1.0000093064131093, 1.0000093841393263, 1.0000094618655433, 1.0000095395917603, 1.0000096173179776, 1.0000096950441946, 1.0000097727704116, 1.0000098504966286, 1.0000099282228456, 1.0000100059490626, 1.0000100836752799, 1.000010161401497, 1.000010239127714, 1.000010316853931, 1.000010394580148, 1.000010472306365, 1.0000105111694735])

# %%
print(len(del1))
print(len(omega1))
# Out:
# 120
# 120

# %%
#0-10
del1_target_values=[0.0626, 0.07011511700126488, 0.07781808464088463, 0.08528731252235024, 0.09252561232632919, 0.09953627253483219, 0.10632298558469415, 0.11288978592381416, 0.11924099550094004, 0.12538116092310436, 0.1313150214749864, 0.13704746128002537, 0.14258346593202448, 0.1479280980321741, 0.15308647180975246, 0.1580637231704054, 0.162864979448481, 0.16749535092036527, 0.17195992276795335, 0.17626372398609969, 0.18041172093460003, 0.18440880330416648, 0.18825978411642774, 0.19196939929507387, 0.19554228187986128, 0.19898296573960586, 0.20229588029414014, 0.20548535048126088, 0.20855559682179, 0.21151074046976706, 0.2143547838168953, 0.2170916139850914, 0.2197250100699584, 0.22225864314078608, 0.22469607624055052, 0.22704076402879042, 0.2292960674376365, 0.23146523256816745, 0.2335513914684538, 0.2355575804690473, 0.23748674018298058, 0.2393417155057674, 0.24112525561540263, 0.24284001373755157, 0.244488560938238, 0.24607339087230434, 0.24759687898979374, 0.2490613254879243, 0.2504689553110891, 0.2518219181508561, 0.25312228844596824, 0.25437206538234336, 0.2555731728930744, 0.2567274565279365, 0.2578367318859555, 0.25890272387293733, 0.25992707556876277, 0.2609113770204691, 0.26185716524225067, 0.26276592421545836, 0.2636390848885999, 0.26447802517733987, 0.2652840699644995, 0.2660584911000569, 0.26680250740114697, 0.26751729059635415, 0.2682040204583055, 0.2688637690148282, 0.2694975720362532, 0.27010643179502225, 0.2706913170656882, 0.2712531631249151, 0.2717928717514777, 0.272311311226262, 0.27280931633226513, 0.2732876883545949, 0.27374719508047035, 0.27418857079922165, 0.2746125101242157, 0.27501972051752316, 0.2754108805347162, 0.27578660364113317, 0.27614748446390364, 0.2764940987919484, 0.27682700357597934, 0.2771467369284995, 0.27745381812380304, 0.2777487475979754, 0.278032006948893, 0.2783040589362236, 0.27856534748142603, 0.2788162976677502, 0.2790573157402372, 0.2792887891057194, 0.27951108737321, 0.2797245928018323, 0.27992964027298156, 0.28012656335770103, 0.28031568295253395, 0.2804973072795233]
omega1_target_values=[1.0, 1.0002053744712585, 1.0001992040515397, 1.0001931005995672, 1.0001870775646282, 1.0001811464936181, 1.0001753170129084, 1.0001695977322709, 1.000163994917078, 1.0001585142393608, 1.00015316022813, 1.0001479358015117, 1.0001428435604998, 1.000137885066431, 1.0001330611039434, 1.0001283720239111, 1.0001238177119913, 1.000119397078641, 1.0001151093429679, 1.0001109527154783, 1.000106925821476, 1.0001030266044477, 1.0000992523260634, 1.0000956012128968, 1.0000920702602558, 1.0000886572139727, 1.00008535944865, 1.000082173958235, 1.0000790974204912, 1.000076127696918, 1.00007326140231, 1.000070495944901, 1.0000678285644389, 1.0000652563321863, 1.0000627761509207, 1.0000603849150695, 1.0000580805143373, 1.000055859776211, 1.0000537202207556, 1.0000516593242852, 1.0000496745193639, 1.0000477631948048, 1.0000459226956717, 1.0000441503393105, 1.0000424445256857, 1.0000408024621597, 1.000039222060177, 1.000037701246406, 1.000036237962736, 1.0000348301662811, 1.000033475829377, 1.000032172939582, 1.0000309194996782, 1.0000297137758816, 1.0000285543088978, 1.0000274391648023, 1.0000263667796738, 1.0000253356214222, 1.0000243441897885, 1.0000233910163452, 1.0000224746644957, 1.0000215937294745, 1.000020746838348, 1.000019932650013, 1.0000191498551978, 1.0000183976066614, 1.000017674527786, 1.0000169795221794, 1.0000163115535299, 1.0000156696132905, 1.0000150527206781, 1.000014459922675, 1.000013890294027, 1.0000133429372453, 1.0000128169826044, 1.0000123115881445, 1.00001182593967, 1.0000113592507491, 1.0000109108258814, 1.0000104800633605, 1.0000100661552194, 1.0000096684711834, 1.0000092863989134, 1.0000089193440056, 1.0000085667299905, 1.0000082279983349, 1.0000079026084394, 1.0000075900376413, 1.0000072897812118, 1.0000070013523572, 1.0000067242822201, 1.0000064581198773, 1.0000062024323406, 1.0000059568045578, 1.0000057208416973, 1.0000054942241603, 1.0000052765544856, 1.000005067476474, 1.0000048666521293, 1.0000046737616586]
del2_target_values=[1.0567, 1.045188644166267, 1.0330710054706214, 1.0210113213972747, 1.0090332602616154, 0.9971584766590975, 0.9854066503172662, 0.9737955751195456, 0.9623412024375818, 0.9510577451624997, 0.9399577659577769, 0.9290522363902008, 0.9183506455189581, 0.9078611045499141, 0.8975904395949054, 0.8875442041910119, 0.8777268657090043, 0.8681418599917079, 0.858791663095336, 0.8496778558459428, 0.840801183463983, 0.832161717736997, 0.8237588570196098, 0.815591383109577, 0.8076575728474491, 0.7999551376359946, 0.7924814305912657, 0.7852334470024374, 0.7782078214475316, 0.7714009038465837, 0.7648088256335095, 0.7584274227993835, 0.7522524111964097, 0.7462793865379225, 0.7405038243983861, 0.7349210740841562, 0.7295264429732695, 0.7243152029969568, 0.7192825349978819, 0.7144236459249871, 0.7097337688334933, 0.7052081628849, 0.7008421133469852, 0.6966309309337182, 0.6925699658688557, 0.6886546826121561, 0.6848805544187692, 0.6812431445201764, 0.677738106124192, 0.6743611824149621, 0.6711082065529649, 0.6679751016750112, 0.6649578808942436, 0.6620526453034479, 0.6592555798457682, 0.6565629864886825, 0.6539712669660425, 0.6514769190840918, 0.6490765367214666, 0.646766809829196, 0.6445445244307014, 0.6424065626217972, 0.6403499025706897, 0.6383716185179783, 0.636468880776655, 0.6346389434371852, 0.632879085319277, 0.6311867598515346, 0.6295594976170278, 0.6279949029167139, 0.6264906537694361, 0.6250445019119255, 0.6236542727987989, 0.6223178656025606, 0.6210332532136014, 0.6197984822401987, 0.6186116730085172, 0.6174710195626075, 0.6163748012240318, 0.6153212765223872, 0.6143087746209519, 0.6133357620533846, 0.6124007510315712, 0.6115022994456257, 0.6106390108638885, 0.6098095345329279, 0.6090125653775392, 0.6082468440007451, 0.6075111566837957, 0.6068043353861684, 0.6061252577455677, 0.6054728470779256, 0.6048460723774013, 0.6042439483163814, 0.6036655327940371, 0.603109854002736, 0.6025760533706005, 0.6020632782874432, 0.6015707078420839, 0.6010975528223498]
omega2_target_values=[1.0, 0.9996812436713708, 0.9996824368233903, 0.9996842784487356, 0.9996867149486116, 0.9996896938572059, 0.9996931648623041, 0.999697077882039, 0.9997013873880721, 0.9997060479332407, 0.9997110163949599, 0.9997162537974418, 0.9997217223283824, 0.9997273855022293, 0.9997332109895083, 0.9997391684484528, 0.9997452292572131, 0.9997513667885094, 0.9997575568380925, 0.999763778017076, 0.9997700097391491, 0.9997762336388972, 0.9997824335718024, 0.9997885938436536, 0.9997947022054877, 0.9998007459977208, 0.9998067144397513, 0.9998125986442775, 0.9998183914624751, 0.9998240843396944, 0.9998296726880795, 0.999835150565756, 0.9998405133609886, 0.9998457577921829, 0.9998508819078844, 0.9998558845413487, 0.9998607621230342, 0.9998655153031657, 0.9998701428142027, 0.9998746441546407, 0.99987901958901, 0.9998832701478777, 0.9998873976278456, 0.9998914045184975, 0.9998952889940841, 0.9998990551420898, 0.9999027042000487, 0.9999062377463274, 0.999909657700124, 0.9999129663214692, 0.9999161662112256, 0.9999192603110875, 0.9999222519035816, 0.9999251431627894, 0.9999279349670758, 0.999930631347703, 0.999933234506908, 0.9999357467434296, 0.9999381704525091, 0.9999405081258901, 0.9999427623518182, 0.9999449358150416, 0.9999470312968104, 0.9999490516748772, 0.9999509999234969, 0.999952875892428, 0.9999546833777068, 0.9999564246254994, 0.9999581016505338, 0.9999597164634283, 0.9999612710706909, 0.9999627674747203, 0.999964207673805, 0.9999655936621235, 0.9999669274297447, 0.9999682109626274, 0.9999694462426206, 0.9999706352474634, 0.9999717794121763, 0.9999728792452283, 0.9999739373454042, 0.999974955125786, 0.9999759339733575, 0.9999768752490046, 0.9999777802875146, 0.9999786503975773, 0.9999794868617832, 0.9999802909366254, 0.9999810638524985, 0.999981806813699, 0.999982520998425, 0.9999832075587766, 0.9999838676207554, 0.999984502284265, 0.9999851125893116, 0.9999856986486229, 0.9999862618212212, 0.999986803036109, 0.9999873231407037, 0.999987822900838]
del3_target_values=[0.9449, 0.9233097919293766, 0.9015941600961741, 0.8809449300929801, 0.8613211152265107, 0.8426809446472738, 0.8249823447176721, 0.808183311417506, 0.7922422287961758, 0.7771182078526278, 0.762771217952042, 0.7491623195217852, 0.7362538298554815, 0.7240093894575943, 0.712393991591014, 0.701374131325954, 0.6909177891355154, 0.6809944319614829, 0.6715749401629179, 0.6626317090608779, 0.6541385840829863, 0.6460707700002781, 0.6384048309271991, 0.6311185759401254, 0.6241910812019784, 0.6176026930846807, 0.6113348243075019, 0.6053699537608782, 0.5996916279365222, 0.5942842847938757, 0.5891333103689427, 0.5842250562857106, 0.5795466088275281, 0.5750857889371048, 0.5708311522165118, 0.5667719919656037, 0.5628981119591714, 0.5591999745600454, 0.5556686992992352, 0.5522958575553165, 0.5490734725544307, 0.5459940193702864, 0.5430504249241577, 0.5402360690055024, 0.5375446381763854, 0.5349701103754473, 0.5325069714583156, 0.5301499593453394, 0.5278940640215889, 0.525734527536856, 0.5236668440056537, 0.5216867596072162, 0.5197902725854994, 0.5179736312879412, 0.5162331134153934, 0.5145652965011241, 0.5129669864191772, 0.5114351200222264, 0.5099667651415755, 0.5085591205871591, 0.507209516147542, 0.5059154125899189, 0.5046744016601152, 0.5034842060825865, 0.5023426795604183, 0.5012477514505317, 0.5001973381425661, 0.49918960086856135, 0.4982227711116383, 0.49729514565494826, 0.4964050865816724, 0.4955510212750226, 0.4947314424182408, 0.49394490799459945, 0.49319004128740107, 0.49246553087997874, 0.4917701306556956, 0.4911026597979452, 0.4904620090199738, 0.4898470260884229, 0.48925662878301646, 0.4886898455429012, 0.4881457363942098, 0.48762339295006146, 0.48712193841056123, 0.4866405275628006, 0.4861783467808568, 0.48573461402579343, 0.48530857884566025, 0.48489952237549305, 0.48450675733731385, 0.4841296280401307, 0.4837675103799379, 0.4834198118397158, 0.48308596961157485, 0.48276539120772366, 0.4824575647208955, 0.4821619805328363, 0.4818781490796237, 0.4816056008516666]
omega3_target_values=[1.0, 0.9994153819800515, 0.9994439144548619, 0.99947138498868, 0.9994977667608494, 0.9995230458073683, 0.9995472199737331, 0.9995702936985236, 0.9995922837403288, 0.9996132104741642, 0.9996330991840697, 0.9996519819547705, 0.9996698904002386, 0.9996868629915544, 0.9997029369955647, 0.9997181493895573, 0.9997325380373921, 0.9997461467116603, 0.9997590103287375, 0.9997711690333667, 0.9997826564183131, 0.9997935092146351, 0.9998037672916854, 0.9998134585130574, 0.9998226183399741, 0.9998312742264673, 0.9998394545993428, 0.9998471889394853, 0.9998545072934587, 0.9998614286130719, 0.9998679797275244, 0.9998741804879541, 0.9998800508358443, 0.9998856108030243, 0.9998908805116689, 0.9998958791094255, 0.9999006182293404, 0.9999051158304734, 0.9999093847079507, 0.999913437476675, 0.9999172865713263, 0.9999209442463608, 0.9999244225760119, 0.9999277333577756, 0.9999308816823401, 0.999933879581994, 0.9999367345414052, 0.9999394538722869, 0.9999420447133966, 0.9999445140305362, 0.9999468686165522, 0.9999491150913359, 0.9999512599018225, 0.9999533079394319, 0.9999552627225269, 0.9999571303434196, 0.9999589148077467, 0.9999606200150091, 0.9999622497585731, 0.9999638077256696, 0.999965297497395, 0.9999667225487104, 0.9999680862484422, 0.9999693918592816, 0.9999706425377849, 0.9999718389663892, 0.9999729848895083, 0.9999740825815765, 0.9999751340816475, 0.9999761413730511, 0.9999771063833934, 0.9999780309845566, 0.9999789169926993, 0.999979766168256, 0.9999805802159379, 0.9999813607847319, 0.9999821094679012, 0.9999828278029856, 0.9999835169135983, 0.9999841773704008, 0.9999848110776461, 0.9999854190822689, 0.9999860024030935, 0.9999865620308351, 0.9999870989280973, 0.9999876140293752, 0.9999881082410522, 0.9999885824414029, 0.9999890374805911, 0.9999894741806706, 0.9999898933355852, 0.9999902957111686, 0.9999906820451442, 0.9999910530471254, 0.999991409378609, 0.9999917511542425, 0.999992079230348, 0.9999923941969832, 0.9999926965909772, 0.9999929868959316]

#10-12
del1_target_values.extend([0.28219986636846206, 0.2803661869724691, 0.2785325075764762, 0.27683350686926583, 0.2752655454561889, 0.27382357801050106, 0.2725027804906217, 0.2712985422486543, 0.27020645965326057, 0.2692223197920996, 0.2683420961012656, 0.2675619364064387, 0.2668781644733521, 0.266287255313291, 0.26578583433998554, 0.26537067221965394, 0.26503866608951526, 0.26478686284689157, 0.2646124203610947, 0.26451260690573])
omega1_target_values.extend([0.9999501226320338, 0.9999528068548206, 0.9999554910776074, 0.9999588587065742, 0.9999620963195919, 0.9999652095997619, 0.999968204075644, 0.9999710849969591, 0.9999738573552345, 0.9999765259661666, 0.9999790953986055, 0.9999815699589507, 0.9999839537688329, 0.9999862507251144, 0.9999884645017957, 0.9999905986509261, 0.9999926564394988, 0.9999946410780498, 0.999996555581811, 0.9999984027659657])
del2_target_values.extend([0.6164532716529219, 0.6232819823145577, 0.6301106929761935, 0.6370646416399101, 0.644140033238103, 0.6513191193896261, 0.6585855040183118, 0.6659240666249162, 0.6733209021102525, 0.6807631972521117, 0.6882391914958208, 0.6957380808546437, 0.7032500174589829, 0.7107659418329588, 0.7182775775900814, 0.7257773821551027, 0.7332584293135437, 0.7407145330808603, 0.7481400116285861, 0.7555296841428225])
omega2_target_values.extend([1.0001813218974618, 1.0001774349596835, 1.0001735480219052, 1.000176843942234, 1.0001796747519898, 1.000182075672221, 1.0001840799346975, 1.0001857187586753, 1.0001870210051913, 1.0001880141826187, 1.0001887235984914, 1.0001891728896584, 1.000189383781818, 1.00018937667362, 1.0001891707197605, 1.0001887831701304, 1.0001882304515146, 1.0001875273526541, 1.0001866877054157, 1.0001857244103487])
del3_target_values.extend([0.4785922663570267, 0.4973002650586255, 0.5160082637602244, 0.5338572280498967, 0.5508972856661974, 0.5671776819208695, 0.5827442252378833, 0.5976395090969703, 0.6119030759468006, 0.6255717880774148, 0.6386799234003054, 0.651259424666294, 0.6633398966880708, 0.6749490557911646, 0.6861127445985149, 0.6968550401509843, 0.7071985466915761, 0.7171640889393903, 0.7267712907627253, 0.7360385830924915])
omega3_target_values.extend([1.000502442029717, 1.0004814282960872, 1.0004604145624574, 1.0004393790522106, 1.0004196306463566, 1.000401078524487, 1.000383639347897, 1.0003672345492063, 1.0003517912545863, 1.0003372432116147, 1.0003235285069438, 1.0003105893392576, 1.0002983721735172, 1.0002868280888542, 1.0002759129170136, 1.0002655839829584, 1.0002558025596338, 1.000246532572456, 1.0002377407078542, 1.0002293964766709])

# %%
t_data = np.linspace(0, 12, 20*(int(12/2))).tolist()

print(len(t_data))
print(len(del3_target_values))
print(len(del1))
# Out:
# 120
# 120
# 120

# %%
# delta1_omega1
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.scatter(t_data, del1_target_values, label='Del1 target', alpha=0.5)
plt.plot(t_data, del1, 'r', label='Del1')
plt.xlabel('Time (t)')
plt.ylabel('Values')
plt.legend()
plt.title('Fitting Data')
plt.grid(True)
print(del1_target_values[-1])


plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 2)
plt.scatter(t_data, omega1_target_values, label='Omega1 target', alpha=0.5)
plt.plot(t_data, omega1, 'r', label='Omega1')
plt.xlabel('Time (t)')
plt.ylabel('Values')
plt.legend()
plt.title('Fitting Data')
plt.grid(True)


# delta2_omega2
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.scatter(t_data, del2_target_values, label='Del2 target', alpha=0.5)
plt.plot(t_data,del2, 'r', label='Del2')
plt.xlabel('Time (t)')
plt.ylabel('Values')
plt.legend()
plt.title('Fitting Data')
plt.grid(True)

plt.subplot(2, 1, 2)
plt.scatter(t_data, omega2_target_values, label='Omega2 target', alpha=0.5)
plt.plot(t_data, omega2, 'r', label='Omega2')
plt.xlabel('Time (t)')
plt.ylabel('Values')
plt.legend()
plt.title('Fitting Data')
plt.grid(True)


# delta3_omega3
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.scatter(t_data, del3_target_values, label='Del3 target', alpha=0.5)
plt.plot(t_data, del3, 'r', label='Del3')
plt.xlabel('Time (t)')
plt.ylabel('Values')
plt.legend()
plt.title('Fitting Data')
plt.grid(True)

plt.subplot(2, 1, 2)
plt.scatter(t_data, omega3_target_values, label='Omega3 target', alpha=0.5)
plt.plot(t_data, omega3, 'r', label='Omega3')
plt.xlabel('Time (t)')
plt.ylabel('Values')
plt.legend()
plt.title('Fitting Data')
plt.grid(True)
# Out:
# 0.26451260690573

# %%
plt.subplot(2, 1, 2)
plt.scatter(t_data, omega3_target_values, label='Omega3 target', alpha=0.5)
plt.plot(t_data, omega3, 'r', label='Omega3')
plt.xlabel('Time (t)')
plt.ylabel('Values')
plt.legend()
plt.title('Fitting Data')
plt.ylim(0.9, 1.5)
# Out:
# (0.9, 1.5)

# %%
plt.subplot(2, 1, 2)
plt.scatter(t_data, omega3_target_values, label='Omega3 target', alpha=0.5)
plt.plot(t_data, omega3, 'r', label='Omega3')
plt.xlabel('Time (t)')
plt.ylabel('Values')
plt.legend()
plt.title('Fitting Data')
plt.grid(True)
